# %% [markdown]
# # Ohmic Dissipation vs Photoionization
#
# gully, March 17, 2023
#
# Updated May 15, 2023

# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.time import Time
from astropy.table import Table
from astropy import units as u
import astropy.constants as const


# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set_context('talk')

plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'

# %% [markdown]
# ### Define Eq. 34 from Thorgren & Fortney 2018

# %%
eps_0 = 2.37
F_0 = 0.14
ess = 0.37

def epsilon_g(F_planet):
    return eps_0 * np.exp(-1* (np.log10(F_planet) - F_0)**2 / (2*ess**2))

# %% [markdown]
# ### Download the Exoplanet Archive
# "Planetary Systems Composite Data"

# %%
#! mv /home/gully/Downloads/PSCompPars_2023.01.13_12.58.07.votable ../../data/ExoplanetArchive/

# %%
table_1 = Table.read('../../data/ExoplanetArchive/PSCompPars_2023.01.13_12.58.07.votable',format='votable')

# %%
df_orig = table_1.to_pandas()

# %%
df_pristine = table_1.to_pandas()

# %%
df_orig.shape
# Out:
# (5241, 313)

# %%
pd.options.display.max_rows=999

# %% [markdown]
# Keep just a few important columns for now

# %%
all_cols = df_orig.columns.values

# %%
keep_cols = [col for col in all_cols if '_reflink' not in col]
#keep_cols = [col for col in keep_cols if 'err1' not in col]
#keep_cols = [col for col in keep_cols if 'err2' not in col]
#keep_cols = [col for col in keep_cols if 'lim' not in col]
keep_cols = [col for col in keep_cols if 'mag' not in col]
keep_cols = [col for col in keep_cols if 'disc_' not in col]
keep_cols = [col for col in keep_cols if '_flag' not in col]

# %%
df_orig = df_orig[keep_cols]

# %%
df_orig['pl_eqt'] = df_orig['pl_eqt'].astype(float)

# %%
df_orig.shape
# Out:
# (5241, 182)

# %% [markdown]
# Let's compute the planet surface gravity:

# %%
grav = const.G * (df_orig.pl_bmasse.values * u.M_earth) / (df_orig.pl_rade.values * u.R_earth)**2
df_orig['pl_grav'] = grav.to(u.m/u.s**2).value
df_orig['pl_grave'] = df_orig.pl_grav/9.8
df_orig['insol_abs'] = df_orig.pl_insol * 1360.9 #W/m^2
df_orig['eps_avg'] = epsilon_g(df_orig['insol_abs']/1e6) # Gerg/s/cm^2

# %% [markdown]
# ### Pick some special objects from the Exoplanet Archive

# %%
s1 = df_orig[df_orig.hostname.str.contains('HAT-P-67')].iloc[0]

# %%
s2 = df_orig[df_orig.hostname.str.contains('189733')].iloc[0]

# %%
s3 = df_orig[df_orig.hostname.str.contains('HAT-P-32')].iloc[0]

# %%
inflated_hot_jup_names = ['HAT-P-1 b','CoRoT-1 b', 'TrES-4 b', 'WASP-12 b', 'WASP-17 b', 'Kepler-7 b']

# %%
inflated_hot_jup_mask = df_orig.pl_name.isin(inflated_hot_jup_names)

# %%
df_orig.pl_name[inflated_hot_jup_mask]
# Out:
# 79       CoRoT-1 b
# 304      HAT-P-1 b
# 4160    Kepler-7 b
# 4982      TrES-4 b
# 5014     WASP-12 b
# 5061     WASP-17 b
# Name: pl_name, dtype: object

# %% [markdown]
# ## Recreate Figure 2 from Thorngen & Fortney 2018

# %% [markdown]
# ![img](https://cfn-live-content-bucket-iop-org.s3.amazonaws.com/journals/1538-3881/155/5/214/revision1/ajaaba13f2_hr.jpg?AWSAccessKeyId=AKIAYDKQL6LTV7YY2HIK&Expires=1679683451&Signature=%2BEyWlIW6FDJ%2F%2FvP430C6sMdGgME%3D)

# %% [markdown]
# First, drop any objects with mass inferred from the Mass-Radius relationship

# %%
inaccurate_masses = df_orig['pl_bmassprov'] == 'M-R relationship'
df_orig = df_orig[~inaccurate_masses].reset_index()

# %% [markdown]
# Let's digitize the plot and overlay the contour trend lines...

# %%
#! mv /Users/mag3842/Downloads/plot-data.csv ../../data/literature/TF2018/inflate500K.csv

# %%
df_2000 = pd.read_csv('../../data/literature/TF2018/inflate2000K.csv', skiprows=1,
                         names=['mass', 'radius'])
df_1500 = pd.read_csv('../../data/literature/TF2018/inflate1500K.csv', skiprows=1,
                         names=['mass', 'radius'])
df_1250 = pd.read_csv('../../data/literature/TF2018/inflate1250K.csv', skiprows=1,
                         names=['mass', 'radius'])
df_1000 = pd.read_csv('../../data/literature/TF2018/inflate1000K.csv', skiprows=1,
                         names=['mass', 'radius'])
df_500 = pd.read_csv('../../data/literature/TF2018/inflate500K.csv', skiprows=1,
                         names=['mass', 'radius'])

# %%
[col for col in df_orig.columns if 'radj' in col]
# Out:
# ['pl_radj', 'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim']

# %%
df_orig['pl_radjerr2']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2427   NaN
# 2428   NaN
# 2429   NaN
# 2430   NaN
# 2431   NaN
# Name: pl_radjerr2, Length: 2432, dtype: float64

# %%
len(df_orig)
# Out:
# 2432

# %%
df_orig['pl_radj'].isna().sum()
# Out:
# 17

# %%
df_orig['pl_radjerr1'].isna().sum()
# Out:
# 1265

# %%
df_orig['pl_bmassjlim'].value_counts()
# Out:
# 0     2287
# 1      112
#         23
# -1      10
# Name: pl_bmassjlim, dtype: int64

# %% [markdown]
# Define the Helium Spectroscopy Metric (HeSM):

# %%
df_orig.pl_bmassj.hist(bins=np.arange(0,20, 1));

# %%
df_orig['tau_infl'] = ((1/df_orig.eps_avg) * 
                       df_orig.pl_bmassj**2 * 
                        1/df_orig.pl_radj**3 * 
                        (1500/df_orig.pl_eqt)**4)* 1000 # Myr

# %% [markdown]
# ### Per CVM request:
# Add a column to to the table for XUV irradiation inflation timescale.

# %%
df_orig.columns.values
# Out:
# array(['index', 'rowid', 'pl_name', 'hostname', 'pl_letter', 'hd_name',
#        'hip_name', 'tic_id', 'gaia_id', 'sy_snum', 'sy_pnum', 'sy_mnum',
#        'discoverymethod', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2',
#        'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2',
#        'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1', 'pl_radeerr2',
#        'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_dens', 'pl_denserr1',
#        'pl_denserr2', 'pl_denslim', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1',
#        'pl_eqterr2', 'pl_eqtlim', 'pl_orbincl', 'pl_orbinclerr1',
#        'pl_orbinclerr2', 'pl_orbincllim', 'pl_tranmid', 'pl_tranmiderr1',
#        'pl_tranmiderr2', 'pl_tranmidlim', 'pl_tranmid_systemref',
#        'pl_imppar', 'pl_impparerr1', 'pl_impparerr2', 'pl_impparlim',
#        'pl_trandep', 'pl_trandeperr1', 'pl_trandeperr2', 'pl_trandeplim',
#        'pl_trandur', 'pl_trandurerr1', 'pl_trandurerr2', 'pl_trandurlim',
#        'pl_ratdor', 'pl_ratdorerr1', 'pl_ratdorerr2', 'pl_ratdorlim',
#        'pl_ratror', 'pl_ratrorerr1', 'pl_ratrorerr2', 'pl_ratrorlim',
#        'pl_occdep', 'pl_occdeperr1', 'pl_occdeperr2', 'pl_occdeplim',
#        'pl_orbtper', 'pl_orbtpererr1', 'pl_orbtpererr2', 'pl_orbtperlim',
#        'pl_orbtper_systemref', 'pl_orblper', 'pl_orblpererr1',
#        'pl_orblpererr2', 'pl_orblperlim', 'pl_rvamp', 'pl_rvamperr1',
#        'pl_rvamperr2', 'pl_rvamplim', 'pl_projobliq', 'pl_projobliqerr1',
#        'pl_projobliqerr2', 'pl_projobliqlim', 'pl_trueobliq',
#        'pl_trueobliqerr1', 'pl_trueobliqerr2', 'pl_trueobliqlim',
#        'st_spectype', 'st_teff', 'st_tefferr1', 'st_tefferr2',
#        'st_tefflim', 'st_rad', 'st_raderr1', 'st_raderr2', 'st_radlim',
#        'st_mass', 'st_masserr1', 'st_masserr2', 'st_masslim', 'st_met',
#        'st_meterr1', 'st_meterr2', 'st_metlim', 'st_metratio', 'st_lum',
#        'st_lumerr1', 'st_lumerr2', 'st_lumlim', 'st_logg', 'st_loggerr1',
#        'st_loggerr2', 'st_logglim', 'st_age', 'st_ageerr1', 'st_ageerr2',
#        'st_agelim', 'st_dens', 'st_denserr1', 'st_denserr2', 'st_denslim',
#        'st_vsin', 'st_vsinerr1', 'st_vsinerr2', 'st_vsinlim', 'st_rotp',
#        'st_rotperr1', 'st_rotperr2', 'st_rotplim', 'st_radv',
#        'st_radverr1', 'st_radverr2', 'st_radvlim', 'rastr', 'ra',
#        'decstr', 'dec', 'glat', 'glon', 'elat', 'elon', 'sy_pm',
#        'sy_pmerr1', 'sy_pmerr2', 'sy_pmra', 'sy_pmraerr1', 'sy_pmraerr2',
#        'sy_pmdec', 'sy_pmdecerr1', 'sy_pmdecerr2', 'sy_dist',
#        'sy_disterr1', 'sy_disterr2', 'sy_plx', 'sy_plxerr1', 'sy_plxerr2',
#        'pl_nnotes', 'st_nphot', 'st_nrvc', 'st_nspec', 'pl_nespec',
#        'pl_ntranspec', 'pl_grav', 'pl_grave', 'insol_abs', 'eps_avg',
#        'tau_infl'], dtype=object)

# %%
def compute_XUV_Mdot(a_AU, m_planet, M_star, R_planet, F_insol_Earth):

    
    # Hardcoded for now:
    eta = 0.4 # "~tens of percent" # HARDCODED
    ## Fxuv =  10**-4.16 * (3e9 * u.erg / u.s / u.cm**2) # HARDCODED
    
    #F_insol_Earth is relative to Earth's insolation.
    F_abs_bol = F_insol_Earth * 1360 * u.Watt/(u.m**2)
    
    Fxuv = 6.3e-4*F_abs_bol # Eq. 5 of Sanz-Forcada et al. 2011
    # Todo: Include a cutoff for older stars outside the saturation regime
    # Fxuv = xuv_func(SpT, Age)
    
    r_Hill = a_AU * (m_planet/(3*M_star))**(1/3)
    rH_by_Rp = (r_Hill/R_planet).to(u.dimensionless_unscaled)
    xi = rH_by_Rp.to(u.dimensionless_unscaled).value
    Kt = 1 - 3/(2*xi) + 1/(2*xi**3)
    
    rho_planet = m_planet / (4/3 * np.pi * R_planet**3)
    rho_planet = rho_planet.to(u.g/u.cm**3)
    
    M_dot = 0.75 * eta * (Fxuv) / (const.G * Kt * rho_planet)
    #M_dot.to(u.Mearth/u.Gyr).value
    tau_infl_XUV = (m_planet/M_dot).to(u.Myr).value
    return tau_infl_XUV

# %%
tau_infl_XUV = compute_XUV_Mdot(df_orig.pl_orbsmax.values*u.AU, 
                 df_orig.pl_bmassj.values*u.Mjup, 
                 df_orig.st_mass.values*u.Msun, 
                 df_orig.pl_radj.values*u.R_jup,
                 df_orig.pl_insol.values)

# %%
df_orig['tau_infl_XUV'] = tau_infl_XUV

# %%
plt.hist(tau_infl_XUV, bins=np.logspace(0, 4, 25))
plt.yscale('log'); plt.xscale('log')

# %%
df_orig.sort_values('tau_infl_XUV').head(15)
# Out:
#       index rowid       pl_name    hostname pl_letter   hd_name   hip_name  \
# 1590   3543  3544   Kepler-33 c   Kepler-33         c
# 2132   4928  4929     TOI-561 b     TOI-561         b
# 333     368   369    HAT-P-67 b    HAT-P-67         b
# 1309   1748  1749     KELT-11 b     KELT-11         b  HD 93396  HIP 52733
# 1425   1935  1936  Kepler-105 b  Kepler-105         b
# 331     366   367    HAT-P-65 b    HAT-P-65         b
# 2120   4912  4913     TOI-500 b     TOI-500         b
# 197     232   233      GJ 367 b      GJ 367         b            HIP 47780
# 2212   5021  5022    WASP-127 b    WASP-127         b
# 1661   3802  3803  Kepler-444 e  Kepler-444         e            HIP 94931
# 1729   4099  4100   Kepler-65 b   Kepler-65         b
# 1591   3544  3545   Kepler-33 d   Kepler-33         d
# 2339   5148  5149     WASP-76 b     WASP-76         b
# 1071   1118  1119    HD 80653 b    HD 80653         b  HD 80653
# 296     331   332    HAT-P-32 b    HAT-P-32         b
#
#              tic_id                       gaia_id sy_snum  ... st_nrvc  \
# 1590  TIC 158935283  Gaia DR2 2127355923723254272       1  ...       0
# 2132  TIC 377064495  Gaia DR2 3850421005290172416       1  ...       0
# 333   TIC 198588220  Gaia DR2 1358614983131339392       2  ...       0
# 1309   TIC 55092869  Gaia DR2 3761497761876022400       1  ...       0
# 1425  TIC 158625964  Gaia DR2 2130368310704421120       1  ...       0
# 331   TIC 283419843  Gaia DR2 1757302881526250496       1  ...       0
# 2120  TIC 134200185  Gaia DR2 5509620021956148736       1  ...       0
# 197    TIC 34068865  Gaia DR2 5412250540681250560       1  ...       0
# 2212  TIC 169226822  Gaia DR2 3778075717162985600       2  ...       0
# 1661  TIC 394172596  Gaia DR2 2101486923385239808       3  ...       0
# 1729  TIC 121731834  Gaia DR2 2102119176929154304       1  ...       0
# 1591  TIC 158935283  Gaia DR2 2127355923723254272       1  ...       0
# 2339  TIC 293435336  Gaia DR2 2512326349403275520       2  ...       0
# 1071   TIC 55315929   Gaia DR2 606477252238780160       1  ...       0
# 296   TIC 292152376   Gaia DR2 356348286886230272       2  ...       0
#
#      st_nspec pl_nespec  pl_ntranspec    pl_grav  pl_grave    insol_abs  \
# 1590        0         0             0   0.373181  0.038080   329011.184
# 2132        0         0             0   7.693827  0.785084  5965396.278
# 333         0         0             0   1.938538  0.197810  3925584.095
# 1309        1         0            47   2.325699  0.237316  1950169.700
# 1425        0         0             0   2.159907  0.220399   465169.229
# 331         0         0             0   3.656821  0.373145  2878112.974
# 2120        0         0             0  10.234022  1.044288  1548704.200
# 197         0         0             0  10.377646  1.058943   798317.549
# 2212        0         0           136   2.375223  0.242370   925126.211
# 1661        0         0             0   3.286774  0.335385   110695.606
# 1729        0         0             0  11.662446  1.190045  3151980.490
# 1591        0         0             0   1.338518  0.136583   168329.721
# 2339        0        25            25   6.809603  0.694857  6993705.927
# 1071        0         0             0  21.089893  2.152030  9030741.874
# 296         0        18            60   4.299201  0.438694  2505416.900
#
#        eps_avg    tau_infl  tau_infl_XUV
# 1590  0.574810    0.555331      3.909899
# 2132  0.541845    3.014480     19.626346
# 333   1.116735    4.408585     39.272159
# 1309  2.182855    3.208603     88.624776
# 1425  1.049038    3.870230    130.388543
# 331   1.633912    9.186352    143.340419
# 2120  2.348486    5.600826    155.604241
# 197   1.927674    3.196440    159.296556
# 2212  2.122444    7.474735    174.791089
# 1661  0.029503  501.763034    175.141726
# 1729  1.481817   10.509677    186.896573
# 1591  0.112236  118.766232    187.350282
# 2339  0.386398   83.126202    191.151080
# 1071  0.208593   89.860224    193.495623
# 296   1.855431   14.303813    207.766298
#
# [15 rows x 189 columns]

# %%
bins = np.logspace(0, 3, 25)

# %%
mask = (df_orig.pl_radj > 0.6) & (df_orig.pl_eqt > 1200) & (df_orig.pl_bmassj < 0.8)

# %%
df_orig['tau_infl'].max()
# Out:
# 3.062264668055186e+44

# %%
plt.plot(df_orig.pl_eqt, df_orig.pl_insol, '.')
plt.yscale('log');plt.xscale('log')

# %%
plt.plot(df_orig.pl_eqt, df_orig.eps_avg, '.')

# %%
plt.hist(df_orig['tau_infl'][mask], bins=bins);
plt.xscale('log')

# %%
df_HeSM = df_orig[mask]

# %%
df_out = df_HeSM.sort_values('tau_infl_XUV', ascending=True)[['pl_name','decstr', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
                                                 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
                                                 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
                                                 'tau_infl', 'tau_infl_XUV']].head(15).reset_index()

# %%
df_out
# Out:
#     index      pl_name         decstr  pl_bmassj  pl_bmassjerr1  \
# 0     333   HAT-P-67 b  +44d46m36.79s     0.3400         0.2500
# 1    1309    KELT-11 b  -09d23m57.71s     0.1710         0.0150
# 2     331   HAT-P-65 b  +11d59m21.72s     0.5270         0.0830
# 3    2212   WASP-127 b  -03d50m06.00s     0.1647         0.0214
# 4     296   HAT-P-32 b  +46d41m16.26s     0.6800         0.1100
# 5    2236   WASP-153 b  +40d01m07.29s     0.3900         0.0200
# 6     355    HATS-26 b  -28d35m08.16s     0.6500         0.0760
# 7    1738   Kepler-7 b  +41d05m23.04s     0.4410         0.0430
# 8     388    HATS-56 b  -45d47m58.04s     0.6020         0.0350
# 9    1450  Kepler-12 b  +50d02m25.32s     0.4320         0.0530
# 10   2153    TOI-954 b  -25d12m31.69s     0.1740         0.0180
# 11   2257   WASP-174 b  -41d23m05.50s     0.3300         0.0910
# 12    330   HAT-P-64 b  +02d25m52.58s     0.5800         0.1800
# 13   2255   WASP-172 b  -47d14m15.27s     0.4700         0.1000
# 14    305   HAT-P-40 b  +45d27m26.43s     0.4800         0.1300
#
#     pl_bmassjerr2  pl_radj  pl_radjerr1  pl_radjerr2  pl_eqt  pl_eqterr1  \
# 0         -0.1900    2.085        0.096       -0.071  1903.0          25
# 1         -0.0150    1.350        0.100       -0.100  1712.0          51
# 2         -0.0830    1.890        0.130       -0.130  1930.0          45
# 3         -0.0172    1.311        0.025       -0.029  1400.0          24
# 4         -0.1000    1.980        0.045       -0.045  1836.0           7
# 5         -0.0200    1.550        0.100       -0.080  1700.0          40
# 6         -0.0760    1.750        0.210       -0.210  1918.0          61
# 7         -0.0420    1.622        0.013       -0.013  1630.0          10
# 8         -0.0350    1.688        0.039       -0.055  1902.0          16
# 9         -0.0510    1.754        0.031       -0.036  1480.0          30
# 10        -0.0170    0.852        0.053       -0.062  1526.0         123
# 11        -0.0910    1.437        0.050       -0.050  1528.0          17
# 12        -0.1300    1.703        0.070       -0.070  1766.0          22
# 13        -0.1000    1.570        0.100       -0.100  1740.0          60
# 14        -0.1300    1.520        0.170       -0.170  1770.0          33
#
#     pl_eqterr2   tau_infl  tau_infl_XUV
# 0          -25   4.408585     39.272159
# 1          -46   3.208603     88.624776
# 2          -45   9.186352    143.340419
# 3          -24   7.474735    174.791089
# 4           -7  14.303813    207.766298
# 5          -40  11.220800    287.167301
# 6          -61  19.142284    360.714876
# 7          -10  14.699311    386.113672
# 8          -16  18.401289    405.817182
# 9          -30  15.621599    420.275363
# 10        -164  20.667501    451.180958
# 11         -17  14.518073    461.208448
# 12         -16  17.334011    473.082276
# 13         -60  14.815975    482.405015
# 14         -33  17.506426    485.137592

# %% [markdown]
# #### Asymmetric error bars

# %%
df_out['mass_str'] = (df_out.pl_bmassj.astype(str)+'^{+'+df_out.pl_bmassjerr1.astype(str)+'}'+
                      '_{'+df_out.pl_bmassjerr2.astype(str)+'}')

df_out['rad_str'] = (df_out.pl_radj.astype(str)+'^{+'+df_out.pl_radjerr1.astype(str)+'}'+
                      '_{'+df_out.pl_radjerr2.astype(str)+'}')

df_out['eqt_str'] = (df_out.pl_eqt.apply(lambda x: 
                      np.format_float_positional(x, precision=3, trim='-',unique=True, fractional=False))
                     +'^{+'+df_out.pl_eqterr1.astype(str)+'}'+
                      '_{'+df_out.pl_eqterr2.astype(str)+'}')

# %% [markdown]
# #### Symmetric error bars

# %%
mask = df_out.pl_bmassjerr1 == -1*df_out.pl_bmassjerr2
df_out['mass_str'][mask] = (df_out.pl_bmassj.astype(str)+'\pm'+df_out.pl_bmassjerr1.astype(str))[mask]
# Out:
# /var/folders/gb/yvbtr8b57pd1nzzxk3t_zwfsxgvdgb/T/ipykernel_53822/612802604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_out['mass_str'][mask] = (df_out.pl_bmassj.astype(str)+'\pm'+df_out.pl_bmassjerr1.astype(str))[mask]

# %%
mask = df_out.pl_radjerr1 == -1*df_out.pl_radjerr2
df_out['rad_str'][mask] = (df_out.pl_radj.astype(str)+'\pm'+df_out.pl_radjerr1.astype(str))[mask]
# Out:
# /var/folders/gb/yvbtr8b57pd1nzzxk3t_zwfsxgvdgb/T/ipykernel_53822/3959794795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_out['rad_str'][mask] = (df_out.pl_radj.astype(str)+'\pm'+df_out.pl_radjerr1.astype(str))[mask]

# %%
mask = df_out.pl_eqterr1.isna()
df_out['eqt_str'][mask] = df_out.pl_eqt.apply(lambda x: 
                      np.format_float_positional(x, precision=3, trim='-',unique=True, fractional=False))[mask]
# Out:
# /var/folders/gb/yvbtr8b57pd1nzzxk3t_zwfsxgvdgb/T/ipykernel_53822/3918318367.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_out['eqt_str'][mask] = df_out.pl_eqt.apply(lambda x:

# %%
df_out['tau_str'] = df_out.tau_infl.apply(lambda x: 
                      np.format_float_positional(x, precision=1, trim='-',unique=True, fractional=False))
df_out['tau_str_XUV'] = df_out.tau_infl_XUV.apply(lambda x: 
                      np.format_float_positional(x, precision=1, trim='-',unique=True, fractional=False))

# %%
file_out = '../../paper/paper1/tables/tab_HeSM.tex'

# %%
str_out = ('\n'.join(df_out[['pl_name', 'mass_str', 'rad_str', 
                             'eqt_str', 'tau_str', 'tau_str_XUV']].to_latex(index=False, 
                                                            escape=False).split('\n')[4:-3]))
# Out:
# /var/folders/gb/yvbtr8b57pd1nzzxk3t_zwfsxgvdgb/T/ipykernel_53822/4219514312.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   str_out = ('\n'.join(df_out[['pl_name', 'mass_str', 'rad_str',

# %%
print(str_out)
# Out:
#  HAT-P-67 b &       0.34^{+0.25}_{-0.19} & 2.085^{+0.096}_{-0.071} &   1900^{+25}_{-25} &       4 &          40 \\
#   KELT-11 b &              0.171\pm0.015 &              1.35\pm0.1 &   1710^{+51}_{-46} &       3 &          90 \\
#  HAT-P-65 b &              0.527\pm0.083 &             1.89\pm0.13 &   1930^{+45}_{-45} &       9 &         100 \\
#  WASP-127 b & 0.1647^{+0.0214}_{-0.0172} & 1.311^{+0.025}_{-0.029} &   1400^{+24}_{-24} &       7 &         200 \\
#  HAT-P-32 b &        0.68^{+0.11}_{-0.1} &            1.98\pm0.045 &     1840^{+7}_{-7} &      10 &         200 \\
#  WASP-153 b &                0.39\pm0.02 &     1.55^{+0.1}_{-0.08} &   1700^{+40}_{-40} &      10 &         300 \\
#   HATS-26 b &               0.65\pm0.076 &             1.75\pm0.21 &   1920^{+61}_{-61} &      20 &         400 \\
#  Kepler-7 b &    0.441^{+0.043}_{-0.042} &           1.622\pm0.013 &   1630^{+10}_{-10} &      10 &         400 \\
#   HATS-56 b &              0.602\pm0.035 & 1.688^{+0.039}_{-0.055} &   1900^{+16}_{-16} &      20 &         400 \\
# Kepler-12 b &    0.432^{+0.053}_{-0.051} & 1.754^{+0.031}_{-0.036} &   1480^{+30}_{-30} &      20 &         400 \\
#   TOI-954 b &    0.174^{+0.018}_{-0.017} & 0.852^{+0.053}_{-0.062} & 1530^{+123}_{-164} &      20 &         500 \\
#  WASP-174 b &               0.33\pm0.091 &            1.437\pm0.05 &   1530^{+17}_{-17} &      10 &         500 \\
#  HAT-P-64 b &       0.58^{+0.18}_{-0.13} &            1.703\pm0.07 &   1770^{+22}_{-16} &      20 &         500 \\
#  WASP-172 b &                 0.47\pm0.1 &              1.57\pm0.1 &   1740^{+60}_{-60} &      10 &         500 \\
#  HAT-P-40 b &                0.48\pm0.13 &             1.52\pm0.17 &   1770^{+33}_{-33} &      20 &         500 \\

# %%
with open(file_out, "w+") as f:
        f.writelines(str_out)

# %% [markdown]
# Caroline advises to:
#
# 1. Drop planets with only upper limits for mass
# 2. Remove uncertain masses.

# %%
uplims = df_orig['pl_bmassjlim'].replace('',np.nan,regex = True).astype(float) == 1

# %%
low_mass_precision = df_orig.pl_bmassj/np.abs(df_orig.pl_bmassjerr2) < 3

# %%
df_orig.pl_bmassjlim.value_counts()
# Out:
# 0     2287
# 1      112
#         23
# -1      10
# Name: pl_bmassjlim, dtype: int64

# %%
limits = df_orig['pl_bmassjlim'].replace('',np.nan,regex = True).astype(float) !=0

# %%
plt.hist(df_orig.pl_bmassj/np.abs(df_orig.pl_bmassjerr2), bins=np.arange(0, 100, 1));
plt.yscale('log')

# %%
df_orig = df_orig[~low_mass_precision & ~limits]

# %%
df_orig
# Out:
#       index rowid     pl_name  hostname pl_letter    hd_name    hip_name  \
# 0         0     1    11 Com b    11 Com         b  HD 107383   HIP 60202
# 1         1     2    11 UMi b    11 UMi         b  HD 136726   HIP 74793
# 2         2     3    14 And b    14 And         b  HD 221345  HIP 116076
# 3         3     4    14 Her b    14 Her         b  HD 145675   HIP 79248
# 4         4     5  16 Cyg B b  16 Cyg B         b  HD 186427   HIP 96901
# ...     ...   ...         ...       ...       ...        ...         ...
# 2425   5234  5235   tau Cet h   tau Cet         h   HD 10700    HIP 8102
# 2426   5235  5236   tau Gem b   tau Gem         b   HD 54719   HIP 34693
# 2427   5236  5237   ups And b   ups And         b    HD 9826    HIP 7513
# 2429   5238  5239   ups And d   ups And         d    HD 9826    HIP 7513
# 2431   5240  5241    xi Aql b    xi Aql         b  HD 188310   HIP 97938
#
#              tic_id                       gaia_id sy_snum  ... st_nphot  \
# 0      TIC 72437047  Gaia DR2 3946945413106333696       2  ...        1
# 1     TIC 230061010  Gaia DR2 1696798367260229376       1  ...        1
# 2     TIC 333225860  Gaia DR2 1920113512486282240       1  ...        1
# 3     TIC 219483057  Gaia DR2 1385293808145621504       1  ...        1
# 4      TIC 27533327  Gaia DR2 2135550755683407232       3  ...        1
# ...             ...                           ...     ...  ...      ...
# 2425  TIC 419015728  Gaia DR2 2452378776434276992       1  ...        1
# 2426   TIC 68984421   Gaia DR2 886479673643096448       1  ...        1
# 2427  TIC 189576919   Gaia DR2 348020448377061376       2  ...        1
# 2429  TIC 189576919   Gaia DR2 348020448377061376       2  ...        1
# 2431  TIC 375464367  Gaia DR2 4298361114750843904       1  ...        1
#
#      st_nrvc st_nspec  pl_nespec  pl_ntranspec     pl_grav   pl_grave  \
# 0          2        0          0             0  412.628943  42.104994
# 1          1        0          0             0  303.415128  30.960727
# 2          1        0          0             0   89.823066   9.165619
# 3          4        1          0             0  159.649607  16.290776
# 4          4        3          0             0   30.416024   3.103676
# ...      ...      ...        ...           ...         ...        ...
# 2425       4       10          0             0   12.662290   1.292070
# 2426       0        0          0             0  438.153901  44.709582
# 2427      10        1          0             0   10.924764   1.114772
# 2429      10        1          0             0  204.292128  20.846136
# 2431       1        0          0             0   50.049210   5.107062
#
#       insol_abs  eps_avg  tau_infl
# 0           NaN      NaN       NaN
# 1           NaN      NaN       NaN
# 2           NaN      NaN       NaN
# 3           NaN      NaN       NaN
# 4           NaN      NaN       NaN
# ...         ...      ...       ...
# 2425        NaN      NaN       NaN
# 2426        NaN      NaN       NaN
# 2427        NaN      NaN       NaN
# 2429        NaN      NaN       NaN
# 2431        NaN      NaN       NaN
#
# [1913 rows x 188 columns]

# %%
df_orig.pl_bmassprov.value_counts()
# Out:
# Mass              1107
# Msini              787
# Msin(i)/sin(i)      19
# Name: pl_bmassprov, dtype: int64

# %%
mask = df_orig.pl_radj/df_orig.pl_radjerr1 > 3

df_orig = df_orig[mask]

# %%
plt.figure(figsize=(8, 5))



sc = plt.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c=df_orig['pl_eqt'], ec='#b2bec3', 
                 vmin=250, vmax=2600, cmap='plasma', linewidths=0.8, s=40)

plt.errorbar(df_orig['pl_bmassj'], df_orig['pl_radj'], 
             xerr=(np.abs(df_orig['pl_bmassjerr2']),np.abs(df_orig['pl_bmassjerr1']) ),
             yerr=(np.abs(df_orig['pl_radjerr2']),df_orig['pl_radjerr1']),
             color='k', alpha=0.3,
             linestyle='none', zorder=-10)



plt.scatter(s1['pl_bmassj'], s1['pl_radj'], c=s1['pl_eqt'], ec='#b2bec3', 
                 vmin=0, vmax=2600, cmap='plasma', linewidths=0.8, zorder=30, s=40)
plt.scatter(s1.pl_bmassj, s1.pl_radj, marker='*', color='k', s=600, ec='k', zorder=19,linewidths=0.8,
               label='HAT-P-67')
plt.axvline(0.5, color='k', linestyle='dotted')
plt.xscale('log')
plt.xlim(5e-2, 1.2e1)
plt.ylim(0,2.3)


plt.plot(df_2000.mass, df_2000.radius, color=sc.cmap(2000/2600), lw=3, zorder=11)
plt.plot(df_2000.mass, df_2000.radius, color='#333333', lw=5)
plt.plot(df_1500.mass, df_1500.radius, color=sc.cmap(1500/2600), lw=3, zorder=11)
plt.plot(df_1500.mass, df_1500.radius, color='#333333', lw=5)
plt.plot(df_1250.mass, df_1250.radius, color=sc.cmap(1250/2600), lw=3, zorder=11)
plt.plot(df_1250.mass, df_1250.radius, color='#333333', lw=5)
plt.plot(df_1000.mass, df_1000.radius, color=sc.cmap(1000/2600), lw=3, zorder=11)
plt.plot(df_1000.mass, df_1000.radius, color='#333333', lw=5)
plt.plot(df_500.mass, df_500.radius, color=sc.cmap(500/2600), lw=3, zorder=11)
plt.plot(df_500.mass, df_500.radius, color='#333333', lw=5)

plt.colorbar(sc, label='Equilibrium Temp. (K)')
plt.xlabel('Planet Mass ($M_\mathrm{J}$)')
plt.ylabel('Planet Radius ($R_\mathrm{J}$)');
plt.savefig('../../paper/paper1/figures/tf2018_fig2_update2023_HAT.png', dpi=300, bbox_inches='tight')

# %%
df_500['Teq']=500; df_1000['Teq']=1000; df_1250['Teq']=1250; df_1500['Teq']=1500;df_2000['Teq']=2000;

# %%
df_theory = pd.concat([df_500, df_1000, df_1250, df_1500, df_2000], ignore_index=True)

# %%
df_theory['insolation'] = (4 * const.sigma_sb * (df_theory['Teq'].values*u.K) **4).to(u.Gerg/u.s/u.cm**2).value

# %%
df_theory['eps_avg'] = epsilon_g(df_theory['insolation'])

# %%
2**(0.25)
# Out:
# 1.189207115002721

# %%
1900/2**(0.25)
# Out:
# 1597.7031889820578

# %% [markdown]
# ## Make a heat-map of $\tau_\mathrm{infl}$
#
# First we need a function that interpolates T_eq...

# %%
import tinygp
import jax
import numpy as np
import jax.numpy as jnp
from tinygp import kernels

jax.config.update("jax_enable_x64", True)

# %%
X = np.vstack([np.log10(df_theory.mass.values), df_theory.radius.values]).T
X.shape
# Out:
# (93, 2)

# %%
ndim = 3

# This kernel is equivalent...
scale = 1.5
kernel1 = kernels.Matern32(scale)

# %%
y = df_theory.Teq.astype(float).values

# For plotting predictions on a grid
x_grid, y_grid = np.linspace(-1.5, 1.5, 200), np.linspace(0, 2.5, 100)
x_, y_ = np.meshgrid(x_grid, y_grid)
X_pred = np.vstack((x_.flatten(), y_.flatten())).T

# For plotting covariance ellipses
theta = np.linspace(0, 2 * np.pi, 500)[None, :]
ellipse = 0.5 * np.concatenate((np.cos(theta), np.sin(theta)), axis=0)

plt.figure(figsize=(6, 6))
plt.scatter(
    X[:, 0], X[:, 1], c=y, ec="black", vmin=y.min(), vmax=y.max()
)
plt.xlabel("x")
plt.ylabel("y")
_ = plt.title("data")

# %%
import jaxopt
from tinygp import GaussianProcess, kernels, transforms


def train_gp(nparams, build_gp_func):
    @jax.jit
    def loss(params):
        return -build_gp_func(params).log_probability(y)

    params = {
        "log_amp": np.float64(0.0),
        "log_scale": np.zeros(nparams),
    }
    solver = jaxopt.ScipyMinimize(fun=loss)
    soln = solver.run(params)
    return build_gp_func(soln.params)

# %%
yerr=100.0*np.ones_like(y)

# %%
def build_gp_corr(params):
    kernel = jnp.exp(params["log_amp"]) * transforms.Cholesky.from_parameters(
        jnp.exp(params["log_scale"][:2]),
        params["log_scale"][2:],
        kernels.ExpSquared(),
    )
    return GaussianProcess(kernel, X, diag=yerr**2)


corr_gp = train_gp(3, build_gp_corr)

# %%
y_pred = corr_gp.condition(y, X_pred).gp.loc.reshape((100, 200))

# %%
flux_pred = (4 * const.sigma_sb * (y_pred*u.K) **4).to(u.Gerg/u.s/u.cm**2).value

# %%
flux_pred.min(), flux_pred.max()
# Out:
# (4.183366408480618e-14, 152.68416467978528)

# %%
eps_pred = epsilon_g(flux_pred)

# %%
scaling_terms = (10**x_)**2 / (y_**3) * (1500/y_pred)**4 * 1000 # in Myr
# Out:
# /var/folders/gb/yvbtr8b57pd1nzzxk3t_zwfsxgvdgb/T/ipykernel_23679/1858968755.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   scaling_terms = (10**x_)**2 / (y_**3) * (1500/y_pred)**4 * 1000 # in Myr

# %%
tau_infl_pred = 1.0/eps_pred * scaling_terms

# %% [markdown]
# Set some boundaries:

# %%
tau_infl_pred = np.array(tau_infl_pred)

# %%
masklo = (y_pred < 450) & (y_ <0.85)
maskmed = (y_pred < 1400) #& (1x_ > 0.5)
maskhi = (y_pred > 2700)

# %%
keep_inds = (10**x_ < 0.5) & (y_>1.1) & (tau_infl_pred<80) & (y_pred>1000) & (10**x_ > 0.08)

# %%
discard = (masklo | maskmed | maskhi) & ~keep_inds

# %%
tau_infl_pred[discard] = np.NaN

# %%
import matplotlib

# %%
font = {'fontname': 'Fira Sans',
        'fontweight': 'ultralight',
        'size': 16,
        }
cmap='Blues'

# %% [markdown]
# Annotate Helium detections and non-detections

# %%
df_nond = pd.read_csv('../../data/literature/dosSantos2022/non_detections.csv', sep='&', 
                      names =['planet', 'facility', 'ref'])

# %%
df_nond['star'] = df_nond['planet'].str[:-1].str.strip()
df_nond['planet letter'] = df_nond['planet'].str[-1]

# %%
df_nond['star'] = df_nond.star.replace({'Gl 436':'GJ 436', 
                                        'TRAPPIST-1 system':'TRAPPIST-1',
                                        'tau Boo':'Tau Boo'})

# %%
df_nond = pd.merge(df_nond, df_pristine, left_on=['star', 'planet letter'], 
         right_on=['hostname', 'pl_letter'], how='left')

# %%
df_detect = pd.read_csv('../../data/literature/dosSantos2022/detections.csv', sep='&', 
                      names =['planet', 'desc'])

# %%
df_detect['planet'] = df_detect.planet.str.strip()
df_detect['planet letter'] = df_detect['planet'].str[-1]
df_detect['star'] = df_detect['planet'].str[:-1].str.strip()

# %%
df_detect['star'] = df_detect.star.replace({'$\\pi$ Men c':'HD 39091', 
                                        'Gl 436':'GJ 436',
                                        'GJ~1214':'GJ 1214'})

# %%
df_pristine.hostname[df_pristine.hostname.str.contains('235088')]
# Out:
# Series([], Name: hostname, dtype: object)

# %%
df_detect.star.values
# Out:
# array(['HD 209458', 'HD 189733', 'KELT-9', 'WASP-12', 'KELT-20',
#        'WASP-52', 'WASP-33', 'WASP-121', 'GJ 436', 'GJ 3470', 'K2-18',
#        'HD 63433', 'HAT-P-11', '$\\pi$ Men', 'WASP-107', 'WASP-69',
#        'HAT-P-32', 'WASP-76', 'WASP-177', 'GJ 1214', 'HAT-P-18', 'NGTS-5',
#        'HAT-P-26', 'V1298 Tau', 'HD 73583', 'TOI-1430', 'TOI-2076',
#        'TOI-1683'], dtype=object)

# %%
df_detect = pd.merge(df_detect, df_pristine, left_on=['star', 'planet letter'], 
         right_on=['hostname', 'pl_letter'], how='left')

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.set_facecolor('#bdc3c7')

plt.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='k',s=1, zorder=10)
plt.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='w',s=3.5, zorder=9)
sc = plt.scatter(df_orig['pl_bmassj'], -1*df_orig['pl_radj'], c=df_orig['pl_eqt'], ec='#b2bec3', 
                 vmin=250, vmax=2600, cmap='plasma', linewidths=0.8, s=40)


plt.scatter(df_nond['pl_bmassj'], df_nond['pl_radj'], c='none',s=20, zorder=20, marker='s', 
            ec='#c0392b', label='He non-detections')

plt.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=20, zorder=20, marker='o', 
            ec='#2ecc71', label='Detections')
plt.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=28, zorder=19, marker='o', 
            ec='k', label=None)


sc2 = plt.pcolor(10**x_, y_, tau_infl_pred, cmap=cmap, 
                 norm=matplotlib.colors.LogNorm(vmin=4, vmax=100,))
#_ = plt.pcolor(10**x_, y_, masklo|maskhi|maskmed, color='k')

#plt.scatter(s1['pl_bmassj'], s1['pl_radj'], c=s1['pl_eqt'], ec='#b2bec3', 
#                 vmin=0, vmax=2600, cmap='plasma', linewidths=0.8, zorder=30, s=40)
plt.scatter(s1.pl_bmassj, s1.pl_radj, marker='*', color='k', s=600, ec='w', zorder=19,linewidths=0.8,
               label=None)#'HAT-P-67')
plt.axvline(0.5, color='k', linestyle='dotted')
plt.xscale('log')
plt.xlim(5e-2, 1.2e1)
plt.ylim(0,2.3)


plt.plot(df_2000.mass, df_2000.radius, color=sc.cmap(2000/2600), lw=2, zorder=11)
plt.plot(df_2000.mass, df_2000.radius, color='#333333', lw=4)
plt.plot(df_1500.mass, df_1500.radius, color=sc.cmap(1500/2600), lw=2, zorder=11)
plt.plot(df_1500.mass, df_1500.radius, color='#333333', lw=4)
plt.plot(df_1250.mass, df_1250.radius, color=sc.cmap(1250/2600), lw=2, zorder=11)
plt.plot(df_1250.mass, df_1250.radius, color='#333333', lw=4)
plt.plot(df_1000.mass, df_1000.radius, color=sc.cmap(1000/2600), lw=2, zorder=11)
plt.plot(df_1000.mass, df_1000.radius, color='#333333', lw=4)
plt.plot(df_500.mass, df_500.radius, color=sc.cmap(500/2600), lw=2, zorder=11)
plt.plot(df_500.mass, df_500.radius, color='#333333', lw=4)

plt.text(1.13, 0.03, 'Non-inflated, stable', color='w', fontdict=font)
plt.text(4.3, 2.02, 'Inflated,\n stable', color='w', fontdict=font)
plt.text(0.083, 1.7, 'Inflated,\n unstable', color='k', fontdict=font, zorder=12, rotation=-40, size=14)

plt.legend(fontsize=11, loc=(0.62, 0.07), frameon=False)

cbar = fig.colorbar(sc2, ticks=[5, 10, 20, 40, 80], label=r'$\tau_\mathrm{infl}$ (Myr)', pad=0.02)
cbar.ax.set_yticklabels(['5', '10', '20', '40', '80'])  # vertically oriented colorbar

plt.xlabel('Planet Mass ($M_\mathrm{J}$)')
plt.ylabel('Planet Radius ($R_\mathrm{J}$)');
plt.savefig('../../paper/paper1/figures/tf2018_fig2_theory.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Add a second panel to compare to XUV photoionization

# %% [markdown]
# We want to mimic Thorngren et al. 2023 figure!

# %%
R_star = 2.546 * u.Rsun
M_star = 1.642 * u.Msun
a_by_R_star = 5.691 
a_AU = (a_by_R_star * R_star).to(u.AU)
m_planet = (0.34 * u.Mjup).to(u.Msun)

# %%
r_Hill = a_AU * (m_planet/(3*M_star))**(1/3)

# %%
R_planet = 2.085 * u.R_jup

# %%
rH_by_Rp = (r_Hill/R_planet).to(u.dimensionless_unscaled)
rH_by_a = (r_Hill/a_AU).to(u.dimensionless_unscaled)

# %%
xi = rH_by_Rp

# %%
Kt = 1 - 3/(2*xi) + 1/(2*xi**3)

# %%
eta = 0.4 # "~tens of percent"

# %%
Fxuv =  10**-4.16 * (3e9 * u.erg / u.s / u.cm**2)

# %%
rho_planet = m_planet / (4/3 * np.pi * R_planet**3)
rho_planet = rho_planet.to(u.g/u.cm**3)

# %%
M_dot = 0.75 * eta * (Fxuv) / (const.G * Kt * rho_planet)

# %%
M_dot
# Out:
# <Quantity 4.21885601e+16 cm erg kg s / (g m3)>

# %%
M_dot.to(u.g/u.s)
# Out:
# <Quantity 4.21885601e+13 g / s>

# %%
M_dot.to(u.Mearth/u.Gyr)
# Out:
# <Quantity 222.92904908 earthMass / Gyr>

# %%
# Out:
# /Users/mag3842/miniforge3/envs/disperse_env/lib/python3.8/site-packages/astropy/units/quantity.py:613: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %% [markdown]
# Compute density

# %%
density_map = 10**x_*u.Mjup/(4/3*np.pi*(y_ * u.R_jup)**3)
# Out:
# /Users/mag3842/miniforge3/envs/disperse_env/lib/python3.8/site-packages/astropy/units/quantity.py:613: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %%
M_dot_map = 0.75 * eta * (Fxuv) / (const.G * Kt * density_map)

# %%
ionization_timescale = 10**x_*u.Mjup / M_dot_map

# %%
ionize_timescale_Myr = ionization_timescale.to(u.Myr).value

# %%
density_map_cgs = density_map.to(u.gram/u.cm**3).value

# %%
fig, axes = plt.subplots(nrows=2, figsize=(8, 10), sharex=True)

ax = axes[0]
ax.set_facecolor('#bdc3c7')

ax.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='k',s=1, zorder=10)
ax.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='w',s=3.5, zorder=9)
sc = ax.scatter(df_orig['pl_bmassj'], -1*df_orig['pl_radj'], c=df_orig['pl_eqt'], ec='#b2bec3', 
                 vmin=250, vmax=2600, cmap='plasma', linewidths=0.8, s=40)


ax.scatter(df_nond['pl_bmassj'], df_nond['pl_radj'], c='none',s=20, zorder=20, marker='s', 
            ec='#c0392b', label='He non-detections')

ax.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=20, zorder=20, marker='o', 
            ec='#2ecc71', label='Detections')
ax.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=28, zorder=19, marker='o', 
            ec='k', label=None)


sc2 = ax.pcolor(10**x_, y_, tau_infl_pred, cmap=cmap, 
                 norm=matplotlib.colors.LogNorm(vmin=4, vmax=1000,))
#_ = plt.pcolor(10**x_, y_, masklo|maskhi|maskmed, color='k')

#plt.scatter(s1['pl_bmassj'], s1['pl_radj'], c=s1['pl_eqt'], ec='#b2bec3', 
#                 vmin=0, vmax=2600, cmap='plasma', linewidths=0.8, zorder=30, s=40)
ax.scatter(s1.pl_bmassj, s1.pl_radj, marker='*', color='k', s=600, ec='w', zorder=19,linewidths=0.8,
               label=None)#'HAT-P-67')
ax.axvline(0.5, color='k', linestyle='dotted')
ax.set_xscale('log')
ax.set_xlim(5e-2, 1.2e1)
ax.set_ylim(0,2.3)


ax.plot(df_2000.mass, df_2000.radius, color=sc.cmap(2000/2600), lw=2, zorder=11)
ax.plot(df_2000.mass, df_2000.radius, color='#333333', lw=4)
ax.plot(df_1500.mass, df_1500.radius, color=sc.cmap(1500/2600), lw=2, zorder=11)
ax.plot(df_1500.mass, df_1500.radius, color='#333333', lw=4)
ax.plot(df_1250.mass, df_1250.radius, color=sc.cmap(1250/2600), lw=2, zorder=11)
ax.plot(df_1250.mass, df_1250.radius, color='#333333', lw=4)
ax.plot(df_1000.mass, df_1000.radius, color=sc.cmap(1000/2600), lw=2, zorder=11)
ax.plot(df_1000.mass, df_1000.radius, color='#333333', lw=4)
ax.plot(df_500.mass, df_500.radius, color=sc.cmap(500/2600), lw=2, zorder=11)
ax.plot(df_500.mass, df_500.radius, color='#333333', lw=4)

ax.text(1.13, 0.03, 'Non-inflated, stable', color='w', fontdict=font)
ax.text(4.3, 2.02, 'Inflated,\n stable', color='w', fontdict=font)
ax.text(0.083, 1.7, 'Inflated,\n unstable', color='k', fontdict=font, zorder=12, rotation=-40, size=14)

ax.legend(fontsize=11, loc=(0.62, 0.07), frameon=False)

cbar = fig.colorbar(sc2, ticks=[5, 50, 500, 1000], label=r'$\tau_\mathrm{infl,OD}$ (Myr)', pad=0.02, ax=ax)
cbar.ax.set_yticklabels(['5', '50', '500', '1000'])  # vertically oriented colorbar
ax.set_ylabel('Planet Radius ($R_\mathrm{J}$)');

ax.set_xticklabels([])

# ----------------------------------- Panel 2  ----------------------------------- 

ax = axes[1]
ax.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='k',s=1, zorder=10)
ax.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='w',s=3.5, zorder=9)
sc = plt.scatter(df_orig['pl_bmassj'], -1*df_orig['pl_radj'], c=df_orig['pl_eqt'], ec='#b2bec3', 
                 vmin=250, vmax=2600, cmap='plasma', linewidths=0.8, s=40)


ax.scatter(df_nond['pl_bmassj'], df_nond['pl_radj'], c='none',s=20, zorder=20, marker='s', 
            ec='#c0392b', label='He non-detections')

ax.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=20, zorder=20, marker='o', 
            ec='#2ecc71', label='Detections')
ax.scatter(df_detect['pl_bmassj'], df_detect['pl_radj'], c='none',s=28, zorder=19, marker='o', 
            ec='k', label=None)

ax.axvline(0.5, color='k', linestyle='dotted')
ax.set_xscale('log')
ax.set_xlim(5e-2, 1.2e1)
ax.set_ylim(0,2.3)


sc2 = ax.pcolor(10**x_, y_, ionize_timescale_Myr, cmap=cmap, 
                 norm=matplotlib.colors.LogNorm(vmin=4, vmax=1000,))
cbar = fig.colorbar(sc2, ticks=[5, 50, 500], label=r'$\tau_\mathrm{infl,XUV} \equiv M/\dot{M}$ (Myr)', pad=0.02, ax=ax)
cbar.ax.set_yticklabels(['5', '50', '500'])  # vertically oriented colorbar

plt.subplots_adjust(wspace=0, hspace=0)

ax.set_xlabel('Planet Mass ($M_\mathrm{J}$)')
ax.set_ylabel('Planet Radius ($R_\mathrm{J}$)');
ax.scatter(s1.pl_bmassj, s1.pl_radj, marker='*', color='k', s=600, ec='w', zorder=19,linewidths=0.8,
               label=None)#'HAT-P-67')

ax.plot(10**x_grid, r_threshold, color='w', linestyle='dashed')


plt.savefig('../../paper/paper1/figures/thorn2023_theory.png', dpi=300, bbox_inches='tight')

# %%
r_threshold = (10**x_grid*u.Mjup/(4/3 * np.pi * 0.1 * u.g/(u.cm**3)  ))**(1/3)
r_threshold = r_threshold.to(u.Rjup).value

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='k',s=1, zorder=10)
plt.scatter(df_orig['pl_bmassj'], df_orig['pl_radj'], c='#bdc3c7',s=3.5, zorder=9)
sc = plt.scatter(df_orig['pl_bmassj'], -1*df_orig['pl_radj'], c=df_orig['pl_eqt'], ec='#b2bec3', 
                 vmin=250, vmax=2600, cmap='plasma', linewidths=0.8, s=40)


sc2 = plt.pcolor(10**x_, y_, eps_pred, vmin=0, vmax=3, cmap='Blues')

#plt.scatter(s1['pl_bmassj'], s1['pl_radj'], c=s1['pl_eqt'], ec='#b2bec3', 
#                 vmin=0, vmax=2600, cmap='plasma', linewidths=0.8, zorder=30, s=40)
plt.scatter(s1.pl_bmassj, s1.pl_radj, marker='*', color='k', s=600, ec='w', zorder=19,linewidths=0.8,
               label='HAT-P-67')
plt.axvline(0.5, color='k', linestyle='dotted')
plt.xscale('log')
plt.xlim(5e-2, 1.2e1)
plt.ylim(0,2.3)


plt.plot(df_2000.mass, df_2000.radius, color=sc.cmap(2000/2600), lw=2, zorder=11)
plt.plot(df_2000.mass, df_2000.radius, color='#333333', lw=4)
plt.plot(df_1500.mass, df_1500.radius, color=sc.cmap(1500/2600), lw=2, zorder=11)
plt.plot(df_1500.mass, df_1500.radius, color='#333333', lw=4)
plt.plot(df_1250.mass, df_1250.radius, color=sc.cmap(1250/2600), lw=2, zorder=11)
plt.plot(df_1250.mass, df_1250.radius, color='#333333', lw=4)
plt.plot(df_1000.mass, df_1000.radius, color=sc.cmap(1000/2600), lw=2, zorder=11)
plt.plot(df_1000.mass, df_1000.radius, color='#333333', lw=4)
plt.plot(df_500.mass, df_500.radius, color=sc.cmap(500/2600), lw=2, zorder=11)
plt.plot(df_500.mass, df_500.radius, color='#333333', lw=4)

plt.colorbar(sc2, label=r'$\epsilon$')
plt.xlabel('Planet Mass ($M_\mathrm{J}$)')
plt.ylabel('Planet Radius ($R_\mathrm{J}$)');
plt.savefig('../../paper/paper1/figures/tf2018_fig2_eps.png', dpi=300, bbox_inches='tight')

# %%
3**4
# Out:
# 81

# %%
df_orig.pl_bmassjlim.value_counts()
# Out:
# 0    842
# Name: pl_bmassjlim, dtype: int64

# %%
mask = (df_orig.pl_bmassj < 0.6) & (df_orig.pl_radj > 1.7)

# %%
mask = (df_orig.pl_bmassj > 1) & (df_orig.pl_bmassj < 10) & (df_orig.pl_radj < 0.6)

# %%
mask2 = mask & (df_orig['pl_bmassjlim'].replace('',np.nan,regex = True).astype(float) == 1)

# %%
mask2.sum()
# Out:
# 0

# %%
df_orig[mask2]
# Out:
# Empty DataFrame
# Columns: [index, rowid, pl_name, hostname, pl_letter, hd_name, hip_name, tic_id, gaia_id, sy_snum, sy_pnum, sy_mnum, discoverymethod, pl_orbper, pl_orbpererr1, pl_orbpererr2, pl_orbperlim, pl_orbsmax, pl_orbsmaxerr1, pl_orbsmaxerr2, pl_orbsmaxlim, pl_rade, pl_radeerr1, pl_radeerr2, pl_radelim, pl_radj, pl_radjerr1, pl_radjerr2, pl_radjlim, pl_bmasse, pl_bmasseerr1, pl_bmasseerr2, pl_bmasselim, pl_bmassj, pl_bmassjerr1, pl_bmassjerr2, pl_bmassjlim, pl_bmassprov, pl_dens, pl_denserr1, pl_denserr2, pl_denslim, pl_orbeccen, pl_orbeccenerr1, pl_orbeccenerr2, pl_orbeccenlim, pl_insol, pl_insolerr1, pl_insolerr2, pl_insollim, pl_eqt, pl_eqterr1, pl_eqterr2, pl_eqtlim, pl_orbincl, pl_orbinclerr1, pl_orbinclerr2, pl_orbincllim, pl_tranmid, pl_tranmiderr1, pl_tranmiderr2, pl_tranmidlim, pl_tranmid_systemref, pl_imppar, pl_impparerr1, pl_impparerr2, pl_impparlim, pl_trandep, pl_trandeperr1, pl_trandeperr2, pl_trandeplim, pl_trandur, pl_trandurerr1, pl_trandurerr2, pl_trandurlim, pl_ratdor, pl_ratdorerr1, pl_ratdorerr2, pl_ratdorlim, pl_ratror, pl_ratrorerr1, pl_ratrorerr2, pl_ratrorlim, pl_occdep, pl_occdeperr1, pl_occdeperr2, pl_occdeplim, pl_orbtper, pl_orbtpererr1, pl_orbtpererr2, pl_orbtperlim, pl_orbtper_systemref, pl_orblper, pl_orblpererr1, pl_orblpererr2, pl_orblperlim, pl_rvamp, pl_rvamperr1, pl_rvamperr2, pl_rvamplim, ...]
# Index: []
#
# [0 rows x 188 columns]

# %%
df_orig['pl_bmassprov'].value_counts()
# Out:
# Mass     840
# Msini      2
# Name: pl_bmassprov, dtype: int64

# %%
df_orig['pl_bmassj'], df_orig['pl_radj'], df_orig['pl_eqt']
# Out:
# (14      13.90000
#  30       0.02514
#  45       0.06330
#  46       0.03020
#  60      15.00000
#  74       7.80000
#  77       6.30000
#  79       1.03000
#  80       2.75000
#  81       2.33000
#  82       0.91700
#  83       1.30800
#  84       7.60000
#  85       0.53500
#  86       2.43000
#  87       3.47000
#  88       1.11000
#  89       3.47000
#  90       4.30000
#  92       2.26000
#  94       2.80000
#  97       0.27000
#  98       0.52000
#  99      10.39000
#  100      0.48400
#  101      0.85000
#  102     21.66000
#  103      2.90000
#  107      0.72000
#  108      0.46700
#  109      2.96000
#  110      0.01283
#  113      0.22000
#  114      0.84000
#  118     11.00000
#  128      0.02429
#  132      0.02753
#  133      0.04616
#  134      0.03203
#  143      0.00522
#  147      0.02571
#  148      0.00415
#  150      0.07142
#  172      0.01051
#  188      0.04373
#  189      0.00585
#  193      0.00579
#  197      0.00172
#  199      0.00551
#  213      0.07000
#  215      0.00887
#  257      0.01545
#  258      0.00264
#  259      0.01271
#  260     19.70000
#  261     20.00000
#  262     16.00000
#  263     11.30000
#  264      1.68000
#  265      0.81700
#  269      0.52500
#  270      0.08400
#  272      0.21100
#  273      0.85100
#  275      3.44000
#  276      1.94000
#  277      4.19300
#  278      0.58000
#  280      0.19700
#  281      0.29200
#  282      8.70000
#  283      7.24600
#  284      4.87000
#  285      2.47000
#  287      0.75000
#  288      0.56900
#  289      0.07000
#  290      0.62000
#  291      0.62600
#  292      0.88000
#  293      0.65000
#  294      0.83000
#  296      0.68000
#  298      3.33000
#  299      1.05600
#  300      1.84820
#  301      1.16900
#  302      0.26700
#  303      0.59900
#  304      0.67100
#  305      0.48000
#  307      1.04400
#  308      0.66200
#  309      0.35200
#  311      0.89200
#  312      0.49300
#  313      2.20000
#  314      0.98000
#  315      1.35000
#  316      0.30900
#  317      0.81800
#  318      1.48400
#  319      0.76000
#  320      0.58200
#  321      2.31000
#  323      0.37200
#  324      1.54000
#  325      1.32000
#  326      0.57400
#  327      1.05700
#  328      0.76100
#  329      0.61400
#  330      0.58000
#  331      0.52700
#  332      0.78300
#  334      0.72400
#  335      3.58000
#  336      1.84000
#  337      6.78000
#  338      1.28000
#  339      0.74900
#  340      1.85500
#  341      0.52600
#  342      0.83000
#  343      2.39000
#  344      0.54300
#  345      1.07100
#  346      2.17000
#  347      3.27000
#  348      1.33800
#  349      1.97950
#  350      1.34500
#  351      2.74000
#  352      1.47000
#  353      2.26000
#  354      0.61300
#  355      0.65000
#  356      0.53000
#  357      0.67200
#  358      0.65300
#  359      1.07100
#  360      0.70600
#  361      0.88000
#  362      0.92000
#  363      1.19200
#  364      0.94100
#  365      1.22200
#  366      3.21600
#  368      0.07400
#  369      0.63000
#  370      1.32300
#  371      1.59000
#  372      9.70000
#  373      1.88000
#  374      0.26100
#  375      0.56000
#  376      0.70000
#  378      0.36900
#  379      0.24300
#  380      0.35300
#  381      0.23700
#  382      0.39000
#  383      0.76800
#  384      2.24000
#  385      0.59500
#  386      0.75300
#  387      0.92100
#  388      0.60200
#  389      3.14700
#  390      1.03000
#  391      0.80600
#  393      0.31900
#  394      0.66200
#  395      3.40000
#  396      0.17900
#  397      0.96000
#  398      0.96000
#  399      0.82100
#  400      5.33000
#  401      1.45000
#  402      1.29000
#  403      0.57700
#  404      0.12000
#  405     12.90000
#  407      0.12540
#  408      1.46000
#  409      0.49100
#  410      2.62900
#  411      1.37400
#  412      0.13800
#  413      0.83700
#  444      0.03964
#  445      0.04782
#  465      0.01432
#  480      8.00000
#  498      2.79000
#  540      0.01485
#  541      0.03536
#  542      0.02775
#  547      0.01271
#  555      0.41500
#  591      0.38000
#  603      0.02363
#  604      0.02552
#  629      0.00698
#  677      3.51000
#  707      0.06198
#  712      0.07583
#  721      1.13000
#  729      0.03146
#  730      0.02517
#  731      0.00881
#  755      1.01700
#  756     11.00000
#  757      0.02335
#  770     28.00000
#  771     12.70000
#  779      0.04531
#  788      0.73000
#  800      0.02778
#  827      0.01491
#  828      0.01372
#  835      0.05223
#  844      0.19000
#  860      0.02618
#  861      0.01073
#  879      0.00673
#  880      0.00972
#  883      1.17000
#  915      0.01488
#  916      0.03357
#  926      0.24400
#  1001     0.02454
#  1021     0.03398
#  1022     0.03492
#  1053     0.03209
#  1054     0.03052
#  1070     4.38000
#  1071     0.01762
#  1092     0.02281
#  1101     0.11000
#  1114     0.06041
#  1122     0.13353
#  1135     0.02611
#  1150     0.04000
#  1176     3.21300
#  1179     9.00000
#  1187    25.00000
#  1198     0.06293
#  1205     7.00000
#  1206    10.00000
#  1207    10.00000
#  1214     0.06859
#  1216     0.84000
#  1217     0.18689
#  1218     0.05254
#  1219     0.01664
#  1221     1.29000
#  1222     2.01000
#  1223     0.84000
#  1224     0.01982
#  1225     0.49000
#  1228     0.01985
#  1229     0.02492
#  1230     0.04081
#  1233     0.38700
#  1234     0.93000
#  1235     0.01598
#  1237     0.01816
#  1238     0.02358
#  1239     0.02807
#  1241     0.03600
#  1242     0.06293
#  1243     0.10194
#  1244     0.03398
#  1246     0.02171
#  1247     0.03901
#  1248     0.02517
#  1250     0.00783
#  1252     0.39800
#  1256     1.36300
#  1257     0.86000
#  1258     0.05978
#  1259     0.04845
#  1260     0.07709
#  1262     1.42000
#  1263     0.18800
#  1264     0.04657
#  1265     0.02058
#  1270     0.09722
#  1271     0.11673
#  1272     0.03046
#  1273     0.04933
#  1276     0.31500
#  1277     0.73000
#  1279     0.77400
#  1280     0.02042
#  1281     0.07709
#  1282     0.33500
#  1283     0.02039
#  1286     0.57900
#  1287     1.77400
#  1288     0.04720
#  1289     0.02549
#  1292     0.26000
#  1294     1.69800
#  1295     0.01227
#  1296     0.02454
#  1301     0.42600
#  1302     0.06702
#  1304     0.48000
#  1305     0.10131
#  1306     0.97000
#  1307    27.23000
#  1308     0.67900
#  1309     0.17100
#  1310     0.95000
#  1311     1.28400
#  1312     1.31000
#  1313     2.75000
#  1314     1.31000
#  1315     1.18000
#  1317     1.70000
#  1320     0.93800
#  1321     5.18000
#  1322     1.94000
#  1323     0.90200
#  1324     0.52000
#  1326     1.39000
#  1327     0.66000
#  1328     2.88000
#  1384     1.45000
#  1385     9.28000
#  1386     0.03000
#  1388     0.01447
#  1389     0.02832
#  1390     0.22339
#  1391     0.04720
#  1399     1.93000
#  1405     0.33400
#  1408     1.09000
#  1410     0.01450
#  1411     0.02319
#  1415     0.16000
#  1420     0.02800
#  1426     0.01447
#  1428     0.03300
#  1432     0.02954
#  1439     0.02300
#  1440     0.02500
#  1446     0.00900
#  1449     1.84000
#  1450     0.43200
#  1455     0.00242
#  1456     0.00283
#  1458     0.13529
#  1460     0.05100
#  1463     0.00022
#  1464     0.00724
#  1465     0.00661
#  1467     8.40000
#  1468     0.11700
#  1469     0.25000
#  1470     0.66000
#  1471     5.28000
#  1472     0.33300
#  1479     0.15000
#  1481     5.88000
#  1483     1.01000
#  1484     2.45000
#  1486     4.16000
#  1487     0.01406
#  1488     0.01705
#  1492     0.01837
#  1493     0.04625
#  1495     0.05400
#  1496     0.05200
#  1500     0.02643
#  1504     0.00636
#  1505     0.00664
#  1506     0.03052
#  1507     0.04012
#  1520     0.02328
#  1521     0.01605
#  1522     0.02517
#  1523     0.01510
#  1537     0.71000
#  1539     0.02750
#  1540     0.04790
#  1543     0.01611
#  1544     0.01951
#  1553     0.20200
#  1561     0.42000
#  1562     0.01300
#  1563     0.01573
#  1564     0.01416
#  1565     0.15300
#  1566     0.13200
#  1567     0.03600
#  1568     2.01000
#  1569     0.07300
#  1571     0.03300
#  1574     0.02341
#  1575     0.01145
#  1592     0.01753
#  1593     0.03020
#  1599     0.22000
#  1603     0.12700
#  1610     0.01205
#  1611     0.02243
#  1619    20.10000
#  1622     0.07700
#  1623     2.20000
#  1624     0.02000
#  1630     0.56000
#  1631     0.08055
#  1632     0.08306
#  1635     0.94100
#  1636     0.21100
#  1643     2.50000
#  1645     0.43000
#  1646     0.59500
#  1647     1.03000
#  1649     0.25000
#  1650     0.34000
#  1651     0.29000
#  1652     1.27000
#  1653     3.23000
#  1654     5.41000
#  1656     2.82000
#  1657     2.86000
#  1658     0.84000
#  1659     1.00000
#  1664     0.50500
#  1666     0.03933
#  1671     0.01905
#  1682     0.04597
#  1689     2.11100
#  1693     0.01300
#  1694     0.02400
#  1699     0.03335
#  1700     0.97000
#  1705     0.03461
#  1709     0.07000
#  1710     0.57000
#  1716     0.05475
#  1717     0.01038
#  1718     0.66800
#  1719     0.01318
#  1720     0.01211
#  1721     0.01309
#  1728     1.01000
#  1730     0.01700
#  1731     0.01300
#  1734     0.02407
#  1738     0.44100
#  1743     0.63000
#  1744    10.10000
#  1745     2.01000
#  1747     0.43000
#  1748     0.00619
#  1752     0.01900
#  1753     0.01300
#  1754     0.59000
#  1755     0.02180
#  1756     0.02121
#  1757     0.02124
#  1758     0.01299
#  1759     0.05400
#  1761     0.03823
#  1762     0.04373
#  1767     0.12600
#  1769     0.06600
#  1771     1.02000
#  1772     0.02000
#  1774     0.13655
#  1775     0.09408
#  1776     0.81000
#  1777     0.20200
#  1778     0.01900
#  1779     0.01430
#  1781     0.03400
#  1783     0.04100
#  1788     0.01900
#  1789     0.01447
#  1791     0.00698
#  1792     0.00610
#  1794     0.02007
#  1795     0.00554
#  1796     0.00733
#  1800     0.09691
#  1804     0.00903
#  1805     0.00485
#  1806     0.00824
#  1807     0.02706
#  1808     0.09225
#  1811     0.81000
#  1812     3.70000
#  1813     3.10000
#  1849     2.16200
#  1850     0.34400
#  1851     0.20800
#  1852     4.84000
#  1853     0.09200
#  1854     0.75100
#  1855     0.66700
#  1856     0.76400
#  1857     0.40900
#  1858     0.74000
#  1859     2.98000
#  1860     2.36000
#  1861     0.61300
#  1862     0.52000
#  1863     0.63900
#  1864     2.38000
#  1865     0.06481
#  1866     0.22900
#  1867     1.33900
#  1868     0.93000
#  1869     2.90000
#  1952     0.62000
#  1953     0.55000
#  1954     1.26000
#  1955     1.18000
#  1956     1.01000
#  1957     1.03000
#  1958     1.39000
#  1959     4.50000
#  1961     3.00000
#  1965     2.31000
#  1977     1.29400
#  1978     0.73600
#  1979     2.49400
#  1980     4.31000
#  1981     6.10000
#  1982     4.32000
#  1983     0.66800
#  1984     1.88000
#  1985     0.37100
#  1986     1.19000
#  1995     3.80000
#  1998     2.96386
#  1999     1.94200
#  2000     0.67000
#  2001     0.03194
#  2003     0.04248
#  2005     0.03131
#  2006     3.35000
#  2007     0.97400
#  2008     1.18000
#  2009     0.01976
#  2010     0.04845
#  2011     0.01856
#  2012     0.02549
#  2013     0.02769
#  2014     0.01668
#  2015     0.04657
#  2016     0.02989
#  2017     0.02086
#  2018     0.04279
#  2019     0.44100
#  2020     0.02693
#  2021     0.04153
#  2025     0.30331
#  2026     0.07740
#  2028    18.50000
#  2029     0.13215
#  2031     0.29800
#  2032     0.35600
#  2033     0.07048
#  2034     2.37000
#  2036     0.02832
#  2037     3.12000
#  2038     0.01218
#  2040     0.01517
#  2041     0.01010
#  2042     0.02089
#  2043     0.85100
#  2044     2.51000
#  2045     3.16000
#  2047     1.18000
#  2048     0.99000
#  2049     1.22000
#  2050     0.01545
#  2052     0.63000
#  2053     0.01189
#  2054     0.79100
#  2055     0.01730
#  2057     0.08904
#  2058     5.42000
#  2059     0.08426
#  2063     0.03398
#  2064     0.00472
#  2065     0.01501
#  2067     0.01214
#  2068     0.02429
#  2070     0.70000
#  2071     0.00809
#  2072     2.30000
#  2073     0.21400
#  2074     0.66000
#  2075     0.42000
#  2076     4.40000
#  2077     2.30000
#  2078     5.02000
#  2080     0.82000
#  2081     0.56000
#  2083     2.75500
#  2084     0.65000
#  2086     0.08181
#  2087     0.04342
#  2090     0.64000
#  2091     1.58000
#  2093     1.60000
#  2094     0.33300
#  2096     0.20100
#  2097     0.13800
#  2098     0.82000
#  2099     0.61000
#  2100     0.02769
#  2101     0.00497
#  2102     0.01935
#  2103     0.01504
#  2104     2.27000
#  2105     5.02900
#  2107     0.26000
#  2108     1.02000
#  2109     0.70000
#  2110     0.26838
#  2111     0.05191
#  2112     1.44000
#  2113     0.02256
#  2114     0.05166
#  2115     0.00966
#  2117     0.03115
#  2118     0.45000
#  2119     1.53000
#  2120     0.00447
#  2124     3.26000
#  2126     0.40000
#  2127     0.19350
#  2129     1.32000
#  2130     3.61000
#  2131     6.01000
#  2132     0.00500
#  2133     0.01699
#  2134     0.03760
#  2135     0.05034
#  2138     6.33000
#  2139     0.88000
#  2140     0.07425
#  2141     1.23600
#  2142     0.03080
#  2143     0.02932
#  2144     0.01259
#  2146     0.05810
#  2148     0.12299
#  2149     0.95000
#  2150     0.66700
#  2153     0.17400
#  2154     0.02863
#  2156     0.00432
#  2157     0.00412
#  2158     0.00122
#  2159     0.00218
#  2160     0.00327
#  2161     0.00416
#  2162     0.00103
#  2174     0.84000
#  2175     1.49000
#  2176     1.91000
#  2177     0.78000
#  2178     1.79000
#  2188     0.85400
#  2189     3.15000
#  2191     0.51000
#  2192     1.49000
#  2193     1.27200
#  2194     1.80000
#  2196     0.09600
#  2198     0.79000
#  2199     0.51000
#  2200     0.47500
#  2201     1.76900
#  2202     0.30000
#  2203     0.51400
#  2204     1.23000
#  2205     1.46500
#  2206     4.85000
#  2207     1.15700
#  2208     0.89900
#  2209     0.60000
#  2210     0.28411
#  2212     0.16470
#  2213     1.00000
#  2214     0.36000
#  2215     1.23000
#  2216     0.27000
#  2217     0.41000
#  2219     1.16000
#  2220     1.90000
#  2221     1.51000
#  2222     1.22000
#  2223     0.11700
#  2224     8.84000
#  2225     2.44000
#  2226     2.69000
#  2227     0.84000
#  2228     0.44000
#  2230     0.27500
#  2231     0.28700
#  2234     8.46000
#  2235     0.31600
#  2236     0.39000
#  2237     0.12800
#  2238     0.57400
#  2239     2.79000
#  2240     0.55000
#  2241     1.24000
#  2242     0.27800
#  2243     2.49000
#  2244     5.20000
#  2245     1.87000
#  2246     2.13000
#  2247     0.65800
#  2248     0.10100
#  2251     0.56100
#  2252     0.78000
#  2253     1.60000
#  2254     1.08400
#  2255     0.47000
#  2256     3.69000
#  2257     0.33000
#  2258     0.99000
#  2259     0.85500
#  2261     1.66000
#  2262    10.20000
#  2264     0.90000
#  2265     0.29900
#  2266     0.14800
#  2268     0.57000
#  2269     0.98000
#  2270     4.22000
#  2271     0.80000
#  2272     1.99000
#  2273     1.15400
#  2274     1.00000
#  2275     2.30000
#  2276     0.93100
#  2277     0.31100
#  2278     0.30000
#  2279     0.67000
#  2280     0.88400
#  2281     1.24000
#  2282     0.44000
#  2283     0.85000
#  2284     0.88900
#  2285     0.23000
#  2286     2.43000
#  2287     0.47800
#  2288     2.63000
#  2289     2.09300
#  2290     0.56000
#  2291     0.71000
#  2292     2.36100
#  2293     1.80000
#  2294     3.44000
#  2295     0.28000
#  2296     1.18600
#  2297     0.85000
#  2299     0.52700
#  2300     1.78000
#  2301     0.87000
#  2302     0.96400
#  2303     1.91000
#  2304     1.14401
#  2306     0.04468
#  2307     0.02130
#  2308     0.80000
#  2309     0.37000
#  2310     1.58000
#  2311     1.46880
#  2312     0.46000
#  2313     2.13200
#  2315     0.59000
#  2316     0.61000
#  2317     0.45000
#  2318     0.64400
#  2319     0.97000
#  2320     0.86300
#  2321     0.37000
#  2323     2.68000
#  2324     0.52000
#  2325     0.37000
#  2326     1.27100
#  2327     1.55000
#  2329     0.43000
#  2330     1.08000
#  2331     0.29000
#  2332     0.96000
#  2333     0.59000
#  2334     1.39000
#  2335     2.30000
#  2336     2.86000
#  2337     0.72000
#  2338     1.07000
#  2339     0.92000
#  2340     1.66700
#  2342     0.85000
#  2343     2.54000
#  2345     0.53800
#  2346     0.72900
#  2347     1.17000
#  2348     0.30000
#  2349     0.69400
#  2350     1.26500
#  2351     2.18000
#  2353     5.90000
#  2354     0.63000
#  2355     1.34000
#  2356     0.80500
#  2357     1.47000
#  2358     0.50000
#  2360     1.44000
#  2361     0.48000
#  2362     1.36000
#  2363     0.92200
#  2364     2.43000
#  2366    13.80000
#  2367    22.00000
#  2368     4.01000
#  2369     1.12000
#  2370     0.59200
#  2375     0.01970
#  2376     0.83000
#  2377     0.56600
#  2380     7.29000
#  2381     1.42000
#  2382     1.19000
#  2384     0.70900
#  2393    11.73313
#  2416     0.01142
#  Name: pl_bmassj, dtype: float64,
#  14      1.440
#  30      0.167
#  45      0.363
#  46      0.289
#  60      1.310
#  74      1.860
#  77      1.110
#  79      1.490
#  80      0.970
#  81      1.430
#  82      1.440
#  83      0.885
#  84      1.090
#  85      1.170
#  86      1.020
#  87      1.310
#  88      1.290
#  89      1.466
#  90      0.840
#  92      1.300
#  94      1.050
#  97      1.080
#  98      1.260
#  99      1.007
#  100     0.955
#  101     0.900
#  102     1.010
#  103     1.009
#  107     1.190
#  108     1.388
#  109     1.166
#  110     0.150
#  113     0.570
#  114     1.066
#  118     2.700
#  128     0.143
#  132     0.174
#  133     0.327
#  134     0.352
#  143     0.101
#  147     0.245
#  148     0.105
#  150     0.233
#  172     0.190
#  188     0.408
#  189     0.113
#  193     0.109
#  197     0.064
#  199     0.097
#  213     0.372
#  215     0.116
#  257     0.141
#  258     0.111
#  259     0.180
#  260     1.470
#  261     3.000
#  262     1.800
#  263     1.265
#  264     1.229
#  265     1.322
#  269     1.319
#  270     0.389
#  272     0.959
#  273     1.272
#  275     1.420
#  276     1.060
#  277     1.289
#  278     1.050
#  280     0.995
#  281     1.132
#  282     0.951
#  283     0.867
#  284     1.110
#  285     1.150
#  287     1.300
#  288     1.135
#  289     0.630
#  290     1.020
#  291     1.212
#  292     1.170
#  293     0.940
#  294     1.440
#  296     1.980
#  298     1.197
#  299     1.332
#  300     1.277
#  301     1.178
#  302     0.825
#  303     1.571
#  304     1.274
#  305     1.520
#  307     1.280
#  308     1.216
#  309     1.242
#  311     1.426
#  312     1.284
#  313     1.590
#  314     1.210
#  315     1.288
#  316     1.293
#  317     1.009
#  318     1.318
#  319     0.944
#  320     1.182
#  321     1.510
#  323     1.332
#  324     1.123
#  325     1.480
#  326     1.631
#  327     0.899
#  328     1.073
#  329     1.119
#  330     1.703
#  331     1.890
#  332     1.590
#  334     1.072
#  335     1.676
#  336     1.510
#  337     1.870
#  338     1.400
#  339     1.393
#  340     1.302
#  341     0.969
#  342     1.609
#  343     0.692
#  344     1.212
#  345     1.039
#  346     1.105
#  347     1.300
#  348     0.777
#  349     1.329
#  350     1.168
#  351     0.953
#  352     1.860
#  353     1.395
#  354     1.260
#  355     1.750
#  356     1.500
#  357     1.194
#  358     1.251
#  359     1.381
#  360     1.175
#  361     1.640
#  362     1.249
#  363     1.230
#  364     1.430
#  365     1.464
#  366     1.153
#  368     0.614
#  369     1.570
#  370     1.020
#  371     1.580
#  372     1.330
#  373     1.400
#  374     1.180
#  375     1.067
#  376     1.286
#  378     1.117
#  379     0.800
#  380     0.765
#  381     0.912
#  382     1.130
#  383     1.410
#  384     1.382
#  385     1.340
#  386     1.015
#  387     1.251
#  388     1.688
#  389     1.139
#  390     1.095
#  391     1.126
#  393     0.998
#  394     1.153
#  395     1.195
#  396     1.055
#  397     1.207
#  398     1.679
#  399     1.501
#  400     1.411
#  401     1.685
#  402     1.232
#  403     0.945
#  404     0.563
#  405     1.384
#  407     0.722
#  408     1.032
#  409     0.884
#  410     1.079
#  411     1.165
#  412     0.873
#  413     1.236
#  444     0.218
#  445     0.388
#  465     0.183
#  480     1.000
#  498     1.172
#  540     0.148
#  541     0.260
#  542     0.229
#  547     0.117
#  555     1.026
#  591     0.740
#  603     0.146
#  604     0.213
#  629     0.115
#  677     1.100
#  707     0.317
#  712     0.232
#  721     1.130
#  729     0.304
#  730     0.285
#  731     0.267
#  755     1.545
#  756     1.290
#  757     0.153
#  770     1.250
#  771     1.460
#  779     0.223
#  788     1.390
#  800     0.156
#  827     0.143
#  828     0.135
#  835     0.420
#  844     0.836
#  860     0.178
#  861     0.167
#  879     0.111
#  880     0.137
#  883     1.440
#  915     0.145
#  916     0.261
#  926     0.867
#  1001    0.219
#  1021    0.267
#  1022    0.259
#  1053    0.249
#  1054    0.213
#  1070    1.070
#  1071    0.144
#  1092    0.193
#  1101    0.660
#  1114    0.288
#  1122    0.347
#  1135    0.189
#  1150    0.220
#  1176    2.030
#  1179    1.500
#  1187    2.000
#  1198    0.244
#  1205    1.200
#  1206    1.200
#  1207    1.200
#  1214    0.346
#  1216    1.426
#  1217    0.476
#  1218    0.228
#  1219    0.162
#  1221    1.083
#  1222    0.932
#  1223    1.076
#  1224    0.134
#  1225    1.300
#  1228    0.205
#  1229    0.213
#  1230    0.302
#  1233    0.813
#  1234    1.210
#  1235    0.135
#  1237    0.183
#  1238    0.195
#  1239    0.211
#  1241    0.225
#  1242    0.240
#  1243    0.624
#  1244    0.366
#  1246    0.154
#  1247    0.254
#  1248    0.156
#  1250    0.089
#  1252    1.000
#  1256    1.445
#  1257    1.300
#  1258    0.482
#  1259    0.669
#  1260    0.306
#  1262    1.552
#  1263    0.850
#  1264    0.215
#  1265    0.153
#  1270    0.400
#  1271    0.669
#  1272    0.231
#  1273    0.315
#  1276    0.847
#  1277    1.190
#  1279    1.006
#  1280    0.142
#  1281    0.235
#  1282    0.897
#  1283    0.177
#  1286    1.039
#  1287    1.060
#  1288    0.473
#  1289    0.280
#  1292    0.774
#  1294    1.227
#  1295    0.128
#  1296    0.278
#  1301    0.683
#  1302    0.222
#  1304    0.947
#  1305    0.464
#  1306    1.046
#  1307    1.110
#  1308    1.399
#  1309    1.350
#  1310    1.780
#  1311    1.743
#  1312    1.740
#  1313    1.415
#  1314    1.525
#  1315    1.570
#  1317    1.350
#  1320    1.323
#  1321    1.272
#  1322    1.560
#  1323    1.699
#  1324    1.300
#  1326    1.600
#  1327    1.620
#  1328    1.891
#  1384    0.940
#  1385    1.512
#  1386    0.307
#  1388    0.170
#  1389    0.170
#  1390    0.790
#  1391    0.485
#  1399    0.990
#  1405    1.005
#  1408    1.030
#  1410    0.132
#  1411    0.207
#  1415    0.510
#  1420    0.198
#  1426    0.117
#  1428    0.223
#  1432    0.142
#  1439    0.278
#  1440    0.374
#  1446    0.143
#  1449    1.101
#  1450    1.754
#  1455    0.128
#  1456    0.120
#  1458    0.225
#  1460    0.215
#  1463    0.057
#  1464    0.135
#  1465    0.135
#  1467    1.136
#  1468    0.236
#  1469    0.385
#  1470    0.960
#  1471    1.108
#  1472    0.754
#  1479    0.448
#  1481    1.070
#  1483    0.906
#  1484    1.310
#  1486    1.066
#  1487    0.181
#  1488    0.183
#  1492    0.312
#  1493    0.779
#  1495    0.490
#  1496    0.623
#  1500    0.197
#  1504    0.072
#  1505    0.077
#  1506    0.167
#  1507    0.272
#  1520    0.267
#  1521    0.307
#  1522    0.467
#  1523    0.410
#  1537    0.194
#  1539    0.245
#  1540    0.465
#  1543    0.248
#  1544    0.243
#  1553    0.300
#  1561    1.034
#  1562    0.239
#  1563    0.227
#  1564    0.209
#  1565    0.256
#  1566    0.583
#  1567    0.348
#  1568    1.097
#  1569    0.785
#  1571    0.321
#  1574    0.217
#  1575    0.196
#  1592    0.359
#  1593    0.398
#  1599    0.764
#  1603    0.728
#  1610    0.134
#  1611    0.328
#  1619    1.240
#  1622    0.357
#  1623    1.170
#  1624    0.128
#  1630    1.290
#  1631    0.214
#  1632    0.394
#  1635    1.341
#  1636    0.388
#  1643    0.960
#  1645    1.150
#  1646    1.192
#  1647    0.890
#  1649    0.978
#  1650    1.090
#  1651    1.230
#  1652    1.080
#  1653    1.219
#  1654    1.145
#  1656    1.450
#  1657    1.130
#  1658    1.990
#  1659    1.090
#  1664    0.960
#  1666    0.234
#  1671    0.210
#  1682    0.242
#  1689    1.426
#  1693    0.803
#  1694    0.865
#  1699    0.198
#  1700    0.747
#  1705    0.229
#  1709    0.581
#  1710    0.874
#  1716    0.331
#  1717    0.090
#  1718    1.304
#  1719    0.153
#  1720    0.170
#  1721    0.178
#  1728    0.906
#  1730    0.230
#  1731    0.136
#  1734    0.210
#  1738    1.622
#  1743    0.960
#  1744    1.050
#  1745    1.360
#  1747    0.960
#  1748    0.100
#  1752    0.639
#  1753    0.311
#  1754    1.416
#  1755    0.238
#  1756    0.244
#  1757    0.136
#  1758    0.143
#  1759    0.216
#  1761    0.363
#  1762    0.476
#  1767    0.199
#  1769    0.194
#  1771    1.204
#  1772    0.548
#  1774    0.740
#  1775    0.721
#  1776    1.367
#  1777    0.313
#  1778    0.232
#  1779    0.140
#  1781    0.313
#  1783    0.305
#  1788    0.132
#  1789    0.124
#  1791    0.124
#  1792    0.136
#  1794    0.146
#  1795    0.104
#  1796    0.111
#  1800    0.419
#  1804    0.116
#  1805    0.102
#  1806    0.119
#  1807    0.205
#  1808    0.421
#  1811    0.890
#  1812    1.500
#  1813    1.530
#  1849    1.205
#  1850    0.817
#  1851    1.048
#  1852    1.142
#  1853    0.444
#  1854    1.100
#  1855    1.300
#  1856    1.240
#  1857    1.210
#  1858    1.595
#  1859    1.070
#  1860    1.330
#  1861    1.267
#  1862    1.214
#  1863    1.023
#  1864    1.480
#  1865    0.284
#  1866    1.136
#  1867    1.326
#  1868    1.090
#  1869    1.070
#  1952    1.250
#  1953    1.019
#  1954    1.093
#  1955    1.200
#  1956    1.130
#  1957    1.360
#  1958    1.363
#  1959    1.610
#  1961    2.720
#  1965    0.941
#  1977    1.143
#  1978    1.543
#  1979    1.254
#  1980    1.096
#  1981    1.135
#  1982    1.107
#  1983    1.062
#  1984    1.700
#  1985    1.285
#  1986    1.009
#  1995    0.810
#  1998    1.004
#  1999    1.117
#  2000    1.490
#  2001    0.202
#  2003    0.231
#  2005    0.160
#  2006    1.300
#  2007    1.500
#  2008    1.300
#  2009    0.215
#  2010    0.326
#  2011    0.151
#  2012    0.269
#  2013    0.224
#  2014    0.313
#  2015    0.337
#  2016    0.243
#  2017    0.246
#  2018    0.261
#  2019    1.022
#  2020    0.215
#  2021    0.246
#  2025    0.812
#  2026    0.369
#  2028    1.090
#  2029    0.467
#  2031    1.231
#  2032    0.841
#  2033    0.305
#  2034    1.396
#  2036    0.353
#  2037    1.490
#  2038    0.125
#  2040    0.149
#  2041    0.114
#  2042    0.184
#  2043    1.060
#  2044    1.255
#  2045    1.360
#  2047    1.286
#  2048    1.239
#  2049    1.489
#  2050    0.160
#  2052    0.987
#  2053    0.152
#  2054    1.086
#  2055    0.181
#  2057    0.476
#  2058    0.965
#  2059    0.451
#  2063    0.280
#  2064    0.103
#  2065    0.149
#  2067    0.197
#  2068    0.204
#  2070    1.440
#  2071    0.112
#  2072    1.140
#  2073    1.040
#  2074    1.150
#  2075    1.008
#  2076    1.117
#  2077    1.440
#  2078    1.347
#  2080    0.960
#  2081    0.901
#  2083    1.010
#  2084    1.017
#  2086    0.313
#  2087    0.270
#  2090    0.995
#  2091    1.282
#  2093    0.900
#  2094    0.925
#  2096    0.975
#  2097    0.639
#  2098    1.217
#  2099    1.760
#  2100    0.247
#  2101    0.108
#  2102    0.210
#  2103    0.190
#  2104    1.158
#  2105    1.142
#  2107    0.740
#  2108    1.124
#  2109    1.010
#  2110    1.071
#  2111    0.535
#  2112    1.211
#  2113    0.239
#  2114    0.454
#  2115    0.114
#  2117    0.294
#  2118    1.500
#  2119    0.990
#  2120    0.104
#  2124    1.060
#  2126    0.830
#  2127    0.519
#  2129    1.009
#  2130    1.086
#  2131    1.091
#  2132    0.127
#  2133    0.257
#  2134    0.226
#  2135    0.238
#  2138    1.060
#  2139    1.771
#  2140    0.468
#  2141    1.170
#  2142    0.203
#  2143    0.235
#  2144    0.165
#  2146    0.261
#  2148    0.307
#  2149    1.070
#  2150    1.171
#  2153    0.852
#  2154    0.247
#  2156    0.100
#  2157    0.098
#  2158    0.070
#  2159    0.082
#  2160    0.093
#  2161    0.101
#  2162    0.067
#  2174    1.130
#  2175    1.360
#  2176    1.336
#  2177    1.610
#  2178    1.194
#  2188    1.483
#  2189    1.080
#  2191    1.430
#  2192    1.528
#  2193    1.137
#  2194    0.960
#  2196    0.940
#  2198    1.110
#  2199    1.238
#  2200    1.409
#  2201    1.339
#  2202    1.060
#  2203    1.440
#  2204    1.400
#  2205    1.937
#  2206    1.473
#  2207    1.753
#  2208    1.318
#  2209    1.240
#  2210    0.931
#  2212    1.311
#  2213    0.930
#  2214    1.220
#  2215    0.890
#  2216    1.220
#  2217    0.897
#  2219    1.210
#  2220    1.300
#  2221    1.380
#  2222    1.090
#  2223    0.800
#  2224    1.380
#  2225    1.440
#  2226    1.210
#  2227    1.530
#  2228    0.850
#  2230    1.115
#  2231    0.756
#  2234    1.070
#  2235    1.187
#  2236    1.550
#  2237    0.510
#  2238    0.998
#  2239    1.070
#  2240    1.380
#  2241    1.220
#  2242    1.090
#  2243    1.143
#  2244    1.000
#  2245    1.202
#  2246    1.128
#  2247    1.260
#  2248    0.630
#  2251    1.304
#  2252    1.870
#  2253    1.096
#  2254    0.980
#  2255    1.570
#  2256    1.200
#  2257    1.437
#  2258    1.208
#  2259    1.505
#  2261    1.810
#  2262    1.240
#  2264    1.240
#  2265    1.184
#  2266    0.850
#  2268    1.330
#  2269    1.250
#  2270    1.110
#  2271    1.640
#  2272    1.619
#  2273    1.415
#  2274    1.150
#  2275    1.230
#  2276    1.081
#  2277    1.462
#  2278    1.070
#  2279    1.230
#  2280    0.962
#  2281    1.380
#  2282    1.070
#  2283    1.210
#  2284    1.219
#  2285    0.770
#  2286    1.420
#  2287    1.549
#  2288    0.960
#  2289    1.593
#  2290    1.000
#  2291    1.300
#  2292    1.327
#  2293    1.160
#  2294    1.230
#  2295    1.270
#  2296    1.321
#  2297    1.100
#  2299    1.122
#  2300    0.930
#  2301    1.100
#  2302    0.946
#  2303    1.174
#  2304    1.128
#  2306    0.318
#  2307    0.161
#  2308    1.500
#  2309    1.110
#  2310    1.087
#  2311    1.166
#  2312    1.270
#  2313    1.074
#  2315    1.580
#  2316    1.330
#  2317    0.940
#  2318    1.050
#  2319    1.430
#  2320    0.775
#  2321    1.030
#  2323    1.410
#  2324    1.320
#  2325    1.410
#  2326    1.271
#  2327    1.112
#  2329    1.150
#  2330    1.320
#  2331    1.110
#  2332    1.330
#  2333    1.164
#  2334    1.180
#  2335    1.290
#  2336    1.420
#  2337    1.360
#  2338    1.270
#  2339    1.830
#  2340    1.230
#  2342    1.670
#  2343    1.130
#  2345    0.999
#  2346    1.429
#  2347    1.620
#  2348    1.040
#  2349    0.942
#  2350    1.240
#  2351    1.385
#  2353    1.040
#  2354    1.630
#  2355    1.030
#  2356    1.461
#  2357    1.597
#  2358    1.580
#  2360    1.230
#  2361    1.200
#  2362    1.140
#  2363    1.144
#  2364    1.020
#  2366    0.928
#  2367    0.934
#  2368    1.490
#  2369    1.363
#  2370    1.031
#  2375    0.182
#  2376    1.140
#  2377    0.993
#  2380    1.410
#  2381    1.250
#  2382    1.140
#  2384    1.373
#  2393    1.650
#  2416    0.184
#  Name: pl_radj, dtype: float64,
#  14         NaN
#  30      1958.0
#  45       593.0
#  46       454.0
#  60      1303.0
#  74      1800.0
#  77       434.0
#  79      1898.0
#  80       600.0
#  81      1657.0
#  82      1442.0
#  83      1700.0
#  84      1952.0
#  85         NaN
#  86      1626.0
#  87      1550.0
#  88      2000.0
#  89      1521.0
#  90      1024.0
#  92         NaN
#  94      1660.0
#  97      1330.0
#  98      1600.0
#  99      1500.0
#  100        NaN
#  101        NaN
#  102     1695.0
#  103        NaN
#  107     1074.0
#  108     1438.0
#  109     1017.0
#  110     1756.0
#  113      870.0
#  114      420.0
#  118     2200.0
#  128     2119.0
#  132     1616.0
#  133      990.0
#  134      752.0
#  143      529.0
#  147      596.0
#  148     1089.0
#  150      422.0
#  172      693.0
#  188      594.0
#  189      773.0
#  193      525.0
#  197     1745.0
#  199      568.0
#  213      686.0
#  215      701.0
#  257     1044.0
#  258      722.0
#  259      605.0
#  260     2300.0
#  261     2650.0
#  262     2300.0
#  263     1050.0
#  264        NaN
#  265        NaN
#  269     1322.0
#  270      838.0
#  272      963.0
#  273     1740.0
#  275     1624.0
#  276      904.0
#  277     1626.0
#  278      792.0
#  280      852.0
#  281     1010.0
#  282     1540.0
#  283      970.0
#  284     1283.0
#  285     1463.0
#  287     1637.0
#  288     1182.0
#  289     1001.0
#  290     1092.0
#  291     1384.0
#  292     1271.0
#  293     1189.0
#  294     1630.0
#  296     1836.0
#  298     1520.0
#  299     1581.0
#  300     1781.0
#  301     1271.0
#  302     1082.0
#  303     1752.0
#  304     1686.0
#  305     1770.0
#  307     1428.0
#  308     1353.0
#  309     1108.0
#  311     1652.0
#  312     1458.0
#  313     2131.0
#  314     1539.0
#  315     1862.0
#  316     1192.0
#  317     1218.0
#  318     1778.0
#  319      818.0
#  320     1313.0
#  321     1840.0
#  323     1622.0
#  324     1278.0
#  325     1675.0
#  326     1772.0
#  327     1505.0
#  328     1512.0
#  329     1237.0
#  330     1766.0
#  331     1930.0
#  332     1896.0
#  334     1028.0
#  335     1930.0
#  336     2733.0
#  337     2562.0
#  338     1700.0
#  339     1540.0
#  340     1359.0
#  341     1407.0
#  342     1596.0
#  343     1446.0
#  344     1244.0
#  345     1276.0
#  346     1505.0
#  347     1592.0
#  348      814.0
#  349     2069.0
#  350     1577.0
#  351      858.0
#  352     1654.0
#  353     2166.0
#  354     1277.0
#  355     1918.0
#  356     1659.0
#  357     1253.0
#  358     1212.0
#  359     1648.0
#  360     1414.0
#  361     1823.0
#  362     1437.0
#  363     1429.0
#  364     1445.0
#  365     2037.0
#  366     1203.0
#  368     1294.0
#  369     1645.0
#  370     1315.0
#  371     2101.0
#  372     1710.0
#  373     1856.0
#  374     1003.0
#  375     1161.0
#  376     1518.0
#  378      853.0
#  379      955.0
#  380      835.0
#  381     1025.0
#  382        NaN
#  383     1553.0
#  384     1834.0
#  385     1312.0
#  386     1429.0
#  387     1367.0
#  388     1902.0
#  389     1413.0
#  390     1721.0
#  391     1128.0
#  393      713.0
#  394     1528.0
#  395     1226.0
#  396     1237.0
#  397     1398.0
#  398     1793.0
#  399     1634.0
#  400     1998.0
#  401     2193.0
#  402     1741.0
#  403     1296.0
#  404     1084.0
#  405     2730.0
#  407      739.0
#  408      895.0
#  409      772.0
#  410      940.0
#  411      828.0
#  412     1324.0
#  413     1746.0
#  444     1153.0
#  445      886.0
#  465     1371.0
#  480        NaN
#  498     1509.0
#  540      905.0
#  541      677.0
#  542      431.0
#  547     2130.0
#  555     1228.0
#  591     1626.0
#  603     1001.0
#  604      642.0
#  629     1478.0
#  677      883.0
#  707      769.0
#  712      863.0
#  721     1209.0
#  729      880.0
#  730      600.0
#  731      540.0
#  755     2132.0
#  756     1040.0
#  757     2141.0
#  770     1429.0
#  771     1182.0
#  779      632.0
#  788     1459.0
#  800     2128.0
#  827     1015.0
#  828      782.0
#  835     1073.0
#  844      789.0
#  860      543.0
#  861      467.0
#  879      709.0
#  880      557.0
#  883     2061.0
#  915     1777.0
#  916      565.0
#  926      876.0
#  1001     943.0
#  1021     911.0
#  1022     684.0
#  1053     714.0
#  1054     498.0
#  1070     405.0
#  1071    2302.0
#  1092    1311.0
#  1101    1089.0
#  1114    1344.0
#  1122     385.0
#  1135     751.0
#  1150     690.0
#  1176    1411.0
#  1179    1500.0
#  1187    2300.0
#  1198     757.0
#  1205    1200.0
#  1206    1200.0
#  1207    1300.0
#  1214    1841.0
#  1216    1649.0
#  1217    1360.0
#  1218     575.0
#  1219    1309.0
#  1221    1098.0
#  1222     701.0
#  1223     619.0
#  1224    2062.0
#  1225    1586.0
#  1228    1012.0
#  1229     888.0
#  1230     757.0
#  1233     524.0
#  1234     962.0
#  1235    2039.0
#  1237     534.0
#  1238       NaN
#  1239     284.0
#  1241     802.0
#  1242     969.0
#  1243     854.0
#  1244     745.0
#  1246     913.0
#  1247     694.0
#  1248    1103.0
#  1250    1818.0
#  1252    1030.0
#  1256    1828.0
#  1257    1587.0
#  1258     709.0
#  1259     560.0
#  1260     494.0
#  1262    1957.0
#  1263    1046.0
#  1264     470.0
#  1265       NaN
#  1270     902.0
#  1271     787.0
#  1272    1089.0
#  1273     741.0
#  1276     804.0
#  1277    1171.0
#  1279     676.0
#  1280    1301.0
#  1281     795.0
#  1282     852.0
#  1283     504.0
#  1286    1092.0
#  1287       NaN
#  1288     837.0
#  1289     634.0
#  1292     650.0
#  1294    1687.0
#  1295    1224.0
#  1296     788.0
#  1301    1400.0
#  1302    1372.0
#  1304    1499.0
#  1305    1092.0
#  1306    1113.0
#  1307    2233.0
#  1308    1377.0
#  1309    1712.0
#  1310    1800.0
#  1311    1970.0
#  1312    1642.0
#  1313    2453.0
#  1314    2087.0
#  1315    2085.0
#  1317    1715.0
#  1320    1561.0
#  1321    1459.0
#  1322    1816.0
#  1323    1823.0
#  1324    1313.0
#  1326    2048.0
#  1327    1675.0
#  1328    4050.0
#  1384     511.0
#  1385    2550.0
#  1386     758.0
#  1388     660.0
#  1389     755.0
#  1390     412.0
#  1391     321.0
#  1399     347.0
#  1405     806.0
#  1408    1459.0
#  1410    2130.0
#  1411     584.0
#  1415    1513.0
#  1420     546.0
#  1426     997.0
#  1428     785.0
#  1432    1379.0
#  1439     653.0
#  1440     582.0
#  1446     507.0
#  1449     704.0
#  1450    1480.0
#  1455     968.0
#  1456     843.0
#  1458     525.0
#  1460     718.0
#  1463     452.0
#  1464     410.0
#  1465     345.0
#  1467    1605.0
#  1468     873.0
#  1469     709.0
#  1470    1251.0
#  1471     388.0
#  1472       NaN
#  1479     651.0
#  1481    2034.0
#  1483     134.0
#  1484    1570.0
#  1486     254.0
#  1487     789.0
#  1488       NaN
#  1492     549.0
#  1493     497.0
#  1495     899.0
#  1496     720.0
#  1500     762.0
#  1504    1084.0
#  1505    1215.0
#  1506    1105.0
#  1507     772.0
#  1520    1042.0
#  1521     947.0
#  1522     827.0
#  1523     751.0
#  1537     568.0
#  1539    1185.0
#  1540     934.0
#  1543     431.0
#  1544     385.0
#  1553     778.0
#  1561     394.0
#  1562       NaN
#  1563     777.0
#  1564     715.0
#  1565     509.0
#  1566     409.0
#  1567     524.0
#  1568     411.0
#  1569     308.0
#  1571     836.0
#  1574     797.0
#  1575     739.0
#  1592     752.0
#  1593     691.0
#  1599       NaN
#  1603       NaN
#  1610     978.0
#  1611     928.0
#  1619     897.0
#  1622    1650.0
#  1623    1620.0
#  1624    1302.0
#  1630    1790.0
#  1631    1138.0
#  1632     838.0
#  1635    1850.0
#  1636       NaN
#  1643     613.0
#  1645    1028.0
#  1646    1605.0
#  1647    1116.0
#  1649    1070.0
#  1650    1300.0
#  1651    1100.0
#  1652    1070.0
#  1653    1620.0
#  1654     812.0
#  1656    1776.0
#  1657    1000.0
#  1658    1729.0
#  1659    1544.0
#  1664    1000.0
#  1666     944.0
#  1671     844.0
#  1682     736.0
#  1689    1750.0
#  1693     439.0
#  1694     381.0
#  1699     380.0
#  1700     388.0
#  1705     487.0
#  1709    1378.0
#  1710    1087.0
#  1716     535.0
#  1717     679.0
#  1718    1460.0
#  1719    1102.0
#  1720    1023.0
#  1721     929.0
#  1728     963.0
#  1730    1246.0
#  1731    1117.0
#  1734    1280.0
#  1738    1630.0
#  1743    1078.0
#  1744     767.0
#  1745    2140.0
#  1747    1440.0
#  1748    2250.0
#  1752     592.0
#  1753     511.0
#  1754    1680.0
#  1755     547.0
#  1756     495.0
#  1757     722.0
#  1758     629.0
#  1759     635.0
#  1761     562.0
#  1762     450.0
#  1767     985.0
#  1769     706.0
#  1771     478.0
#  1772     403.0
#  1774     661.0
#  1775     523.0
#  1776    2040.0
#  1777     975.0
#  1778     781.0
#  1779    1037.0
#  1781     997.0
#  1783     927.0
#  1788     810.0
#  1789     965.0
#  1791     553.0
#  1792     416.0
#  1794     379.0
#  1795     709.0
#  1796     595.0
#  1800     700.0
#  1804     424.0
#  1805     508.0
#  1806     892.0
#  1807     353.0
#  1808    1978.0
#  1811       NaN
#  1812    2570.0
#  1813    2100.0
#  1849    1332.0
#  1850     435.0
#  1851    1257.0
#  1852    1605.0
#  1853    1143.0
#  1854    1146.0
#  1855    1177.0
#  1856    1457.0
#  1857    1381.0
#  1858    1468.0
#  1859     688.0
#  1860    1357.0
#  1861    1327.0
#  1862    1499.0
#  1863    1101.0
#  1864    1434.0
#  1865    1650.0
#  1866     952.0
#  1867    1284.0
#  1868    1345.0
#  1869    1448.0
#  1952    1702.0
#  1953    1019.0
#  1954    1342.0
#  1955    2013.0
#  1956    1550.0
#  1957    1686.0
#  1958    2212.0
#  1959    2034.0
#  1961    1204.0
#  1965       NaN
#  1977    1418.0
#  1978    1955.0
#  1979    1344.0
#  1980    1681.0
#  1981    1385.0
#  1982    1415.0
#  1983    1006.0
#  1984    2053.0
#  1985    1457.0
#  1986    1134.0
#  1995       NaN
#  1998       NaN
#  1999     974.0
#  2000    1762.0
#  2001    1077.0
#  2003     784.0
#  2005    1323.0
#  2006    1728.0
#  2007     637.0
#  2008    2073.0
#  2009     703.0
#  2010     330.0
#  2011     775.0
#  2012     955.0
#  2013     860.0
#  2014     586.0
#  2015     462.0
#  2016    1037.0
#  2017     828.0
#  2018     638.0
#  2019     963.0
#  2020     871.0
#  2021     651.0
#  2025     919.0
#  2026     961.0
#  2028     408.0
#  2029    1266.0
#  2031    1562.0
#  2032    1388.0
#  2033    1395.0
#  2034    1679.0
#  2036     867.0
#  2037    2370.0
#  2038    2316.0
#  2040     326.0
#  2041     682.0
#  2042     338.0
#  2043     918.0
#  2044    1404.0
#  2045    1840.0
#  2047    1588.0
#  2048    1619.0
#  2049    1669.0
#  2050     924.0
#  2052     684.0
#  2053    1069.0
#  2054    1715.0
#  2055     590.0
#  2057     659.0
#  2058    1198.0
#  2059     767.0
#  2063     443.0
#  2064    1040.0
#  2065     873.0
#  2067     600.0
#  2068     521.0
#  2070    1927.0
#  2071    2100.0
#  2072    1375.0
#  2073    1208.0
#  2074     362.0
#  2075     759.0
#  2076    1167.0
#  2077    2486.0
#  2078    3646.0
#  2080    1188.0
#  2081     497.0
#  2083     348.0
#  2084    1491.0
#  2086    1860.0
#  2087     805.0
#  2090    1259.0
#  2091    1688.0
#  2093    1812.0
#  2094    1534.0
#  2096    1352.0
#  2097    1027.0
#  2098    1431.0
#  2099    1182.0
#  2100     531.0
#  2101     581.0
#  2102     488.0
#  2103     387.0
#  2104    1488.0
#  2105     643.0
#  2107     690.0
#  2108     801.0
#  2109     750.0
#  2110     759.0
#  2111     463.0
#  2112    1570.0
#  2113     981.0
#  2114     674.0
#  2115    1862.0
#  2117     633.0
#  2118    1866.0
#  2119    1370.0
#  2120    1617.0
#  2124     906.0
#  2126     565.0
#  2127     867.0
#  2129     441.0
#  2130    1061.0
#  2131    1180.0
#  2132    2480.0
#  2133     860.0
#  2134       NaN
#  2135       NaN
#  2138    1586.0
#  2139    1749.0
#  2140     635.0
#  2141    1252.0
#  2142    1038.0
#  2143     800.0
#  2144     514.0
#  2146    1253.0
#  2148    1932.0
#  2149    1397.0
#  2150    1192.0
#  2153    1526.0
#  2154     941.0
#  2156     398.0
#  2157     340.0
#  2158     286.0
#  2159     250.0
#  2160     218.0
#  2161     197.0
#  2162     172.0
#  2174    1140.0
#  2175    1466.0
#  2176    1638.0
#  2177    1778.0
#  2178    1480.0
#  2188    1812.0
#  2189    1370.0
#  2191    1560.0
#  2192    2508.0
#  2193    1516.0
#  2194     900.0
#  2196     736.0
#  2198     992.0
#  2199       NaN
#  2200    1496.0
#  2201    2043.0
#  2202    1001.0
#  2203    1729.0
#  2204    1600.0
#  2205    2593.0
#  2206    1880.0
#  2207    2720.0
#  2208    1520.0
#  2209    1400.0
#  2210    1480.0
#  2212    1400.0
#  2213    1100.0
#  2214    1531.0
#  2215     833.0
#  2216    1460.0
#  2217     763.0
#  2219    1790.0
#  2220    1211.0
#  2221    1742.0
#  2222    1590.0
#  2223     910.0
#  2224    1872.0
#  2225    1320.0
#  2226    1540.0
#  2227    2000.0
#  2228    1260.0
#  2230    1404.0
#  2231     940.0
#  2234    1460.0
#  2235    1312.0
#  2236    1700.0
#  2237     970.0
#  2238    1193.0
#  2239    1590.0
#  2240    1850.0
#  2241    1389.0
#  2242    1119.0
#  2243    1557.0
#  2244     910.0
#  2245    1638.0
#  2246    1610.0
#  2247    1624.0
#  2248    1270.0
#  2251    1604.0
#  2252    1755.0
#  2253    1422.0
#  2254    1642.0
#  2255    1740.0
#  2256    1880.0
#  2257    1528.0
#  2258    1571.0
#  2259    1721.0
#  2261    2470.0
#  2262    2429.0
#  2264    1540.0
#  2265    1186.0
#  2266    1479.0
#  2268    1480.0
#  2269    1160.0
#  2270    1347.0
#  2271    1760.0
#  2272    3353.0
#  2273    2113.0
#  2274    1500.0
#  2275    1620.0
#  2276    1311.0
#  2277    1379.0
#  2278    1340.0
#  2279    1502.0
#  2280    1077.0
#  2281    1772.0
#  2282    1210.0
#  2283    1650.0
#  2284    1456.0
#  2285     970.0
#  2286    2020.0
#  2287    1307.0
#  2288    1388.0
#  2289    2782.0
#  2290    1250.0
#  2291    1338.0
#  2292    1733.0
#  2293    1232.0
#  2294    1250.0
#  2295    1166.0
#  2296    1673.0
#  2297    1244.0
#  2299    1021.0
#  2300    1427.0
#  2301    1337.0
#  2302    1153.0
#  2303    1636.0
#  2304    1275.0
#  2306       NaN
#  2307       NaN
#  2308    2035.0
#  2309    1400.0
#  2310    1706.0
#  2311    1395.0
#  2312    1315.0
#  2313    1053.0
#  2315    1759.0
#  2316    1300.0
#  2317    1216.0
#  2318    1338.0
#  2319    1270.0
#  2320     670.0
#  2321    1184.0
#  2323    1624.0
#  2324    1475.0
#  2325    1470.0
#  2326    1689.0
#  2327    1480.0
#  2329    1003.0
#  2330    1490.0
#  2331     963.0
#  2332    1487.0
#  2333    1387.0
#  2334    2049.0
#  2335    2210.0
#  2336    1790.0
#  2337    1926.0
#  2338    1710.0
#  2339    2160.0
#  2340    1715.0
#  2342    1716.0
#  2343     875.0
#  2345     825.0
#  2346    1623.0
#  2347    2190.0
#  2348    1120.0
#  2349     797.0
#  2350    1452.0
#  2351    2050.0
#  2353    1120.0
#  2354    1840.0
#  2355    1160.0
#  2356    1871.0
#  2357    1942.0
#  2358    1604.0
#  2360    1570.0
#  2361    1285.0
#  2362    1555.0
#  2363    1171.0
#  2364    1480.0
#  2366     163.0
#  2367     450.0
#  2368    1500.0
#  2369    2000.0
#  2370    2198.0
#  2375     790.0
#  2376    1210.0
#  2377    1328.0
#  2380    1729.0
#  2381    1630.0
#  2382    1230.0
#  2384    1743.0
#  2393    1612.0
#  2416    1170.0
#  Name: pl_eqt, dtype: float64)

# %%
df_orig.iloc[0]
# Out:
# index                                             14
# rowid                                             15
# pl_name                    2MASS J02192210-3925225 b
# hostname                     2MASS J02192210-3925225
# pl_letter                                          b
# hd_name
# hip_name
# tic_id                                  TIC 77111651
# gaia_id                 Gaia DR2 4963614887043956096
# sy_snum                                            1
# sy_pnum                                            1
# sy_mnum                                            0
# discoverymethod                              Imaging
# pl_orbper                                        NaN
# pl_orbpererr1                                    NaN
# pl_orbpererr2                                    NaN
# pl_orbperlim
# pl_orbsmax                                     156.0
# pl_orbsmaxerr1                                  10.0
# pl_orbsmaxerr2                                 -10.0
# pl_orbsmaxlim                                      0
# pl_rade                                       16.141
# pl_radeerr1                                    0.336
# pl_radeerr2                                   -0.336
# pl_radelim                                         0
# pl_radj                                         1.44
# pl_radjerr1                                     0.03
# pl_radjerr2                                    -0.03
# pl_radjlim                                         0
# pl_bmasse                                   4417.837
# pl_bmasseerr1                                349.613
# pl_bmasseerr2                               -349.613
# pl_bmasselim                                       0
# pl_bmassj                                       13.9
# pl_bmassjerr1                                    1.1
# pl_bmassjerr2                                   -1.1
# pl_bmassjlim                                       0
# pl_bmassprov                                    Mass
# pl_dens                                         5.77
# pl_denserr1                                      NaN
# pl_denserr2                                      NaN
# pl_denslim                                         0
# pl_orbeccen                                      NaN
# pl_orbeccenerr1                                  NaN
# pl_orbeccenerr2                                  NaN
# pl_orbeccenlim
# pl_insol                                         NaN
# pl_insolerr1                                     NaN
# pl_insolerr2                                     NaN
# pl_insollim
# pl_eqt                                           NaN
# pl_eqterr1                                      <NA>
# pl_eqterr2                                      <NA>
# pl_eqtlim
# pl_orbincl                                       NaN
# pl_orbinclerr1                                   NaN
# pl_orbinclerr2                                   NaN
# pl_orbincllim
# pl_tranmid                                       NaN
# pl_tranmiderr1                                   NaN
# pl_tranmiderr2                                   NaN
# pl_tranmidlim
# pl_tranmid_systemref
# pl_imppar                                        NaN
# pl_impparerr1                                    NaN
# pl_impparerr2                                    NaN
# pl_impparlim
# pl_trandep                                       NaN
# pl_trandeperr1                                   NaN
# pl_trandeperr2                                   NaN
# pl_trandeplim
# pl_trandur                                       NaN
# pl_trandurerr1                                   NaN
# pl_trandurerr2                                   NaN
# pl_trandurlim
# pl_ratdor                                        NaN
# pl_ratdorerr1                                    NaN
# pl_ratdorerr2                                    NaN
# pl_ratdorlim
# pl_ratror                                        NaN
# pl_ratrorerr1                                    NaN
# pl_ratrorerr2                                    NaN
# pl_ratrorlim
# pl_occdep                                        NaN
# pl_occdeperr1                                    NaN
# pl_occdeperr2                                    NaN
# pl_occdeplim
# pl_orbtper                                       NaN
# pl_orbtpererr1                                   NaN
# pl_orbtpererr2                                   NaN
# pl_orbtperlim
# pl_orbtper_systemref
# pl_orblper                                       NaN
# pl_orblpererr1                                   NaN
# pl_orblpererr2                                   NaN
# pl_orblperlim
# pl_rvamp                                         NaN
# pl_rvamperr1                                     NaN
# pl_rvamperr2                                     NaN
# pl_rvamplim
# pl_projobliq                                     NaN
# pl_projobliqerr1                                 NaN
# pl_projobliqerr2                                 NaN
# pl_projobliqlim
# pl_trueobliq                                     NaN
# pl_trueobliqerr1                                 NaN
# pl_trueobliqerr2                                 NaN
# pl_trueobliqlim
# st_spectype                                       M6
# st_teff                                       3064.0
# st_tefferr1                                     76.0
# st_tefferr2                                    -76.0
# st_tefflim                                         0
# st_rad                                          0.28
# st_raderr1                                      0.01
# st_raderr2                                     -0.01
# st_radlim                                          0
# st_mass                                         0.11
# st_masserr1                                     0.01
# st_masserr2                                    -0.01
# st_masslim                                         0
# st_met                                           NaN
# st_meterr1                                       NaN
# st_meterr2                                       NaN
# st_metlim
# st_metratio
# st_lum                                         -2.23
# st_lumerr1                                      0.06
# st_lumerr2                                     -0.06
# st_lumlim                                          0
# st_logg                                         4.59
# st_loggerr1                                     0.06
# st_loggerr2                                    -0.06
# st_logglim                                         0
# st_age                                         0.035
# st_ageerr1                                     0.005
# st_ageerr2                                    -0.005
# st_agelim                                          0
# st_dens                                     17.67076
# st_denserr1                                  0.13736
# st_denserr2                                 -0.13736
# st_denslim                                         0
# st_vsin                                          6.5
# st_vsinerr1                                      0.4
# st_vsinerr2                                     -0.4
# st_vsinlim                                         0
# st_rotp                                          NaN
# st_rotperr1                                      NaN
# st_rotperr2                                      NaN
# st_rotplim
# st_radv                                         10.6
# st_radverr1                                      0.7
# st_radverr2                                     -0.7
# st_radvlim                                         0
# rastr                                   02h19m22.25s
# ra                                         34.842705
# decstr                                 -39d25m23.08s
# dec                                       -39.423077
# glat                                       -67.98402
# glon                                       252.45343
# elat                                       -49.30514
# elon                                        13.50901
# sy_pm                                          109.6
# sy_pmerr1                                        0.1
# sy_pmerr2                                        NaN
# sy_pmra                                        103.6
# sy_pmraerr1                                      0.1
# sy_pmraerr2                                      NaN
# sy_pmdec                                       -35.9
# sy_pmdecerr1                                     0.1
# sy_pmdecerr2                                     NaN
# sy_dist                                    40.089641
# sy_disterr1                                  0.19405
# sy_disterr2                                 -0.19405
# sy_plx                                       24.9441
# sy_plxerr1                                  0.120739
# sy_plxerr2                                 -0.120739
# pl_nnotes                                          0
# st_nphot                                           0
# st_nrvc                                            0
# st_nspec                                           0
# pl_nespec                                          0
# pl_ntranspec                                       0
# pl_grav                                   166.151358
# pl_grave                                    16.95422
# insol_abs                                        NaN
# eps_avg                                          NaN
# tau_infl                                         NaN
# Name: 14, dtype: object

# %%
plt.figure(figsize=(8, 6))
plt.plot()
# Out:
# []

# %%
grid = sns.displot(x=df_orig.st_teff, y=df_orig.st_lum, height=7, alpha=1)
#grid.ax.plot(df_orig.st_teff,df_orig.st_lum,'.',alpha=1) #hr diagram

grid.ax.scatter(s1.st_teff, s1.st_lum, marker='*', color='#f39c12', s=500, ec='k', 
               label='HAT-P-67')

grid.ax.text(7100, 1.3, 'HAT-P-67')

grid.ax.set_xlim(8000,2000)
grid.ax.set_ylim(-5,4)
grid.ax.set_xscale('linear')
grid.ax.set_xlabel('$T_\mathrm{eff}$ [K]' )
grid.ax.set_ylabel('$\log{L/L_\odot}$')

plt.savefig('../../figures/ExoArchive_HRD2023_hist_HAT.png', dpi=300, bbox_inches='tight')

# %%
jupiter_insolation = (1/5.2038)**2
jupiter_gravity = 24.79 # m/s

# %%
mask = df_orig.hostname.str.contains('TRAPPIST-1')
mask.sum()
# Out:
# 7

# %% [markdown]
# ### Read in the solar system data

# %%
df = pd.read_csv('../../data/solar_system/ss_data_fact_sheet_nasa.csv', 
            sep='\t', skipfooter=1, engine='python', 
            na_values=['Unknown*', 'Unknown']).set_index('Unnamed: 0').T

df.index.name = 'Planet'
df.columns.name = None
df = df.reset_index()
df = df.drop(index=3).reset_index() # Drop the moon
df = df.drop(index=8).reset_index() # Drop Pluto @PlutoKiller

df['pl_rade'] = (df['Diameter (km)'].str.replace(',', '').astype(float).values/2*\
                 1*u.km/(1*u.Rearth)).to(u.dimensionless_unscaled).value

df['pl_bmasse'] = (df['Mass (1024kg)'].astype(float).values*1e24*\
                 1*u.kg/(1*u.M_earth)).to(u.dimensionless_unscaled).value

df['pl_grave'] = df['Gravity (m/s2)'].astype(float).values/9.8

df['pl_orbsmax'] = (df['Distance from Sun (106 km)'].astype(float).values*1e6 *\
                     1*u.km/(1*u.AU)).to(u.dimensionless_unscaled).value

df = df[['Planet']+df.columns[-4:].values.tolist()]

df['pl_insol'] = 1/df.pl_orbsmax**2

df['Initial'] = ['Me','V', 'E','Ma','J','S','U','N']

# %%
df_orig = df_pristine

# %%
(4 * const.sigma_sb * (df_theory['Teq'].values*u.K) **4).to(u.Gerg/u.s/u.cm**2).value

# %%
grid.ax

# %%
sns.set_context('paper', font_scale=1.7)

# %%
grid = sns.displot(x=df_orig.pl_insol, y=df_orig.pl_rade, height=7, alpha=1, log_scale=True)
#grid.ax.plot(df_orig.pl_insol,df_orig.pl_rade,'.',alpha=0.0, zorder=-1)

grid.ax.set_xlabel(r'Instellation [$S_\oplus$] $\propto \frac{\mathrm{power}}{\mathrm{area}}$' )
grid.ax.set_ylabel('Planet Radius [$R_\oplus$]');

grid.ax.scatter(s1.pl_insol, s1.pl_rade, marker='*', color='#f39c12', s=300, ec='k', 
               label='HAT-P-67', linewidth=1)
#grid.ax.text(8_000, 3, 'HAT-P-67 b')

#grid.ax.scatter(s2.pl_insol, s2.pl_rade, marker='o', color='#e74c3c', s=100, ec='k', 
#               label='HD 189733 b')
#grid.ax.text(900, 30, 'HD 189733 b', color='w', fontsize=14)


grid.ax.scatter(df.pl_insol, df.pl_rade, marker='s', color='#f1c40f', ec='k')
for i in range(len(df)):
    planet = df.iloc[i]
    grid.ax.annotate(planet.Initial, (planet.pl_insol*1.05, planet.pl_rade *1.08), fontsize=12)

#grid.ax.scatter(df_orig.pl_insol[inflated_hot_jup_mask], df_orig.pl_rade[inflated_hot_jup_mask],
#           marker='o', color='g', ec='w', zorder=10)

#grid.ax.plot(df_orig.pl_insol[mask],df_orig.pl_rade[mask],'o',alpha=1, zorder=1)

grid.ax.scatter(df_detect['pl_insol'], df_detect['pl_rade'], c='#2ecc71',s=22, zorder=22, marker='o', 
            ec='k', label='Detections', linewidth=0.6)
grid.ax.scatter(df_nond['pl_insol'], df_nond['pl_rade'], c='none',s=20, zorder=18, marker='x', 
            ec='k', label='He non-detections', linewidth=1)

#plt.scatter(df_detect['pl_insol'], df_detect['pl_rade'], c='k',s=24, zorder=19, marker='o', 
#            ec='none', label=None)

#ax2 = grid.ax.twiny()
#new_tick_locations = np.array([1e4, 1e2, 1e0, 1e-2])
#new_tick_locations = np.array([4, 2, 0, -2])
#def tick_function(X):
#    V = (X*1360.9/4/const.sigma_sb.value)**(0.25)
#    return ["{:d}".format(int(z)) for z in V]

#ax2.set_xlim(grid.ax.get_xlim())
#ax2.set_xticks(new_tick_locations)
#ax2.set_xticklabels(tick_function(new_tick_locations))
#ax2.set_xlabel(r"$T_\mathrm{eq}\;$ (K)")

grid.ax.annotate('Small planet radius gap', (1e3, 1.35), 
                 fontsize=11, rotation=-18, color='w')

grid.ax.annotate('Hot\nNeptune\nDesert', (2e4, 7), 
                 fontsize=11, rotation=10, color='k')

#grid.ax.annotate('Inflated\n   Hot \n.     Jupiters', (5e2, 19.5), 
#                 fontsize=11, rotation=0, color='k')


grid.ax.legend(fontsize=10, loc='lower right')

grid.ax.set_xlim(3e4,9e-4)
grid.ax.set_xscale('log')
plt.savefig('../../paper/paper1/figures/HAT-P-67b_radius_valley.png', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.kdeplot(x=df_orig.pl_insol, y=df_orig.pl_grave, alpha=1, shade=False,
                   log_scale=True, zorder=2, ax=ax, levels=[0.05, 0.1, 0.25, 0.5, ])

ax.plot(df_orig.pl_insol,df_orig.pl_grave,'.',alpha=0.1, zorder=1, color='k')

ax.scatter(s1.pl_insol, s1.pl_grave, marker='*', color='#f39c12', s=500, ec='k', 
               label='HAT-P-67')
ax.text(8_000, 0.1, 'HAT-P-67 b')

#grid.ax.scatter(s2.pl_insol, 21.2, marker='o', color='#e74c3c', s=100, ec='k', 
#               label='HD 189733 b')
#grid.ax.text(900, 30, 'HD 189733 b', color='w', fontsize=14)

ax.scatter(df.pl_insol, df.pl_grave, marker='s', color='#f1c40f', ec='k', zorder=10)
for i in range(len(df)):
    planet = df.iloc[i]
    plt.annotate(planet.Initial, (planet.pl_insol*1.2, planet.pl_grave /1.55), fontsize=12, zorder=10)


#ax.scatter(df_orig.pl_insol[inflated_hot_jup_mask], df_orig.pl_grave[inflated_hot_jup_mask],
#           marker='o', color='g', ec='w', zorder=10)
#for i in range(len(df)):
#    planet = df.iloc[i]
#    plt.annotate(planet.Initial, (planet.pl_insol*1.2, planet.pl_grave /1.55), fontsize=12, zorder=10)



ax.set_xlim(3e4,2e-4)
#grid.ax.set_ylim(6,2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'Instellation [$S_\oplus$] $\propto \frac{\mathrm{power}}{\mathrm{unit\,\;area}}$' )
ax.set_ylabel('Planet Surface Gravity [g]');

plt.savefig('../../figures/HAT-P-67b_low_surface_gravity.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Plot of Atmospheric scale height versus $R_\mathrm{Hill}/R_p$
#
# I predict that HAT-P-67b will stand out in this diagram.

# %%
df_orig['pl_eqt'] = df_orig['pl_eqt'].astype(float)

# %%
scale_heights_A = const.k_B * (5000.0 * u.Kelvin)/(df_orig.pl_grav.values * u.m/u.s**2)/(2.3*const.m_p)
scale_heights_B = const.k_B * (5000.0 * u.Kelvin)/(df_orig.pl_grav.values * u.m/u.s**2)/(18.0*const.m_p)

# %%
scale_heights_A = const.k_B * (df_orig['pl_eqt'].values * u.Kelvin)/(df_orig.pl_grav.values * u.m/u.s**2)/(2.3*const.m_p)
scale_heights_B = const.k_B * (df_orig['pl_eqt'].values * u.Kelvin)/(df_orig.pl_grav.values * u.m/u.s**2)/(18.0*const.m_p)

# %%
df_orig['scale_height'] = scale_heights_A.to(u.km).value

# %%
mask = df_orig['pl_rade'] < 1.5

# %%
df_orig['scale_height'][mask] = scale_heights_B.to(u.km).value[mask]

# %%
r_Hill = df_orig['pl_orbsmax'].values*u.AU*(df_orig['pl_bmassj'].values*u.M_jup / (3.0*df_orig['st_mass'].values*u.M_sun))**(1/3)

# %%
r_Hill.to(u.km)
# Out:
# <Quantity [25423009.60966181, 27247934.67412802, 10994501.44328011, ...,
#            51088996.27313703,  8449080.02647519,  7526249.74687986] km>

# %%
r_Hill_minus_r_planet = r_Hill.to(u.km) - (df_orig['pl_radj'].values*u.R_jup).to(u.km)

# %%
df_orig['r_Hill_minus_r_planet'] = r_Hill_minus_r_planet.value

# %%
baseline = np.array([1,1e11])

# %%
mask = df_orig.pl_name == 'HAT-P-67 b'

# %%
df_orig['N_H'] = df_orig['r_Hill_minus_r_planet']/df_orig['scale_height']

# %%
df_orig['N_H'][mask]
# Out:
# 368    69.298019
# Name: N_H, dtype: float64

# %%
plt.hist(np.log10(df_orig['N_H']), bins=np.arange(0, 5, 0.05));

# %%
mask = df_orig['pl_bmassprov'] == 'Mass'

# %%
fig, ax = plt.subplots(figsize=(8, 5))
mask = df_orig['pl_bmassprov'] == 'Mass'
ax.plot(df_orig.r_Hill_minus_r_planet[mask],df_orig.scale_height[mask],'.',alpha=0.1, zorder=-1, color='#3498db')
ax.plot(baseline, baseline, 'k--', label='1')
ax.plot(baseline, baseline/10, ':', label='10', color='#c0392b')
ax.plot(baseline, baseline/100, '-.', label='100', color='#f1c40f')
ax.plot(baseline, baseline/1000, '-.', label='1,000', color='#27ae60')
ax.plot(baseline, baseline/10000, '-', label='10,000', color='#8e44ad')


mask = df_orig.pl_name == 'HAT-P-67 b'
#ax.scatter(df_orig.r_Hill_minus_r_planet[mask],df_orig.scale_height[mask],marker='*', color='#f39c12', s=500, ec='k', 
#               label='HAT-P-67')
#ax.text(8_000, 0.1, 'HAT-P-67 b')

#27ae60'
plt.yscale('log')
plt.xscale('log')
ax.set_xlabel('$R_\mathrm{Hill} - R_p$ [km]')
ax.set_ylabel('Scale Height $H$ [km]')
ax.set_xlim(1e3)
ax.set_ylim(1e0, 1e5)
plt.legend(title='$N_H$')
plt.savefig('../../figures/scale_height_vs_Hill_Radius_population.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Surface gravity versus mass
#
#
# Visualizing [this pileup](https://ui.adsabs.harvard.edu/abs/2016AsBio..16..325B/abstract)

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(df_orig.r_Hill_minus_r_planet,df_orig.scale_height,'.',alpha=0.1, zorder=-1)
plt.yscale('log')
plt.xscale('log')
ax.set_xlabel('$R_\mathrm{Hill}$ [km]')
ax.set_ylabel('Scale Height $H$ [km]')
# Out:
# Text(0, 0.5, 'Scale Height $H$ [km]')

# %%
ax.scatter(df.pl_bmasse, df.pl_grave, marker='s', color='#f1c40f', ec='k', zorder=10)
for i in range(len(df)):
    planet = df.iloc[i]
    plt.annotate(planet.Initial, (planet.pl_bmasse/1.2, planet.pl_grave /1.7), fontsize=12, zorder=10)

ax.scatter(df_orig.pl_insol[inflated_hot_jup_mask], df_orig.pl_grave[inflated_hot_jup_mask],
           marker='o', color='g', ec='w', zorder=10)

ax.scatter(s1.pl_bmasse, s1.pl_grave, marker='*', color='#f39c12', s=500, ec='k', 
               label='HAT-P-67')
ax.text(11, 0.08, 'HAT-P-67 b')

ax.set_xlabel('$M_\mathrm{p}\; [M_\odot]$')
ax.set_ylabel('Surface gravity [g]')
ax.set_xscale('log')
ax.set_xlim(1e-3, 2e4)
ax.set_yscale('log')
ax.set_ylim(1e-2, 1e2)
# Out:
# (0.01, 100.0)

# %%
grid.ax.plot(df_orig.pl_insol[mask],df_orig.pl_grav[mask],'o',alpha=1, zorder=1)

grid.ax.scatter(s1.pl_insol, s1.pl_grav, marker='*', color='#f39c12', s=500, ec='k', 
               label='HAT-P-67')
grid.ax.text(8_000, 3, 'HAT-P-67 b')

grid.ax.scatter(s2.pl_insol, s1.pl_grav, marker='o', color='#e74c3c', s=100, ec='k', 
               label='HD 189733 b')
#grid.ax.text(900, 30, 'HD 189733 b', color='w', fontsize=14)

grid.ax.scatter(1, 9.8, marker='o', ec='k', s=100, color='#27ae60', 
               label='Earth')
grid.ax.scatter(1, 9.8, marker='+', s=100, color='k', 
               label='Earth')

grid.ax.scatter(jupiter_insolation, jupiter_gravity, marker='s', s=100, color='#9b59b6', ec='k',
               label='Jupiter')



grid.ax.set_xlim(3e4,1e-2)
#grid.ax.set_ylim(6,2)
grid.ax.set_xscale('log')
grid.ax.set_yscale('log')
grid.ax.set_xlabel(r'Instellation [$S/S_\oplus$] $\propto \frac{\mathrm{power}}{\mathrm{area}}$' )
grid.ax.set_ylabel('Planet Surface Gravity [m/s$^2$]');

#plt.savefig('../../figures/ExoArchive_HRD2023_hist_HAT.png', dpi=300, bbox_inches='tight')

# %%
plt.plot(df_orig.st_vsin,df_orig.st_rotp,'.')
plt.xlim(-5,60)
plt.ylim(-5,250) #inversely relates
# Out:
# (-5.0, 250.0)

# %%
df_orig.hostname.value_counts() #duplicates? merged values,see how many planets in system with hostname
# Out:
# KOI-351              8
# TRAPPIST-1           7
# HD 34445             6
# Kepler-20            6
# Kepler-11            6
#                     ..
# NGC 2682 Sand 364    1
# Kepler-1392          1
# Kepler-1253          1
# Kepler-1680          1
# Kepler-1430          1
# Name: hostname, Length: 3254, dtype: int64

# %%
df=df_orig[['hostname','st_teff','st_rad','st_mass','st_logg','sy_refname','ra','dec']] #need rv, vsini
df
# Out:
#       hostname  st_teff  st_rad  st_mass  st_logg  \
# 0       11 Com      NaN     NaN     2.60      NaN
# 1       11 Com   4742.0   19.00     2.70     2.31
# 2       11 UMi   4340.0   24.08     1.80     1.60
# 3       11 UMi      NaN     NaN     1.70      NaN
# 4       11 UMi   4213.0   29.79     2.78     1.93
# ...        ...      ...     ...      ...      ...
# 29382  ups And      NaN     NaN      NaN      NaN
# 29383  ups And      NaN    1.56     1.30      NaN
# 29384  ups And      NaN     NaN      NaN      NaN
# 29385   xi Aql   4780.0   12.00     2.20     2.66
# 29386   xi Aql      NaN     NaN     1.40      NaN
#
#                                               sy_refname          ra  \
# 0      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  185.178772
# 1      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  185.178772
# 2      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  229.274597
# 3      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  229.274597
# 4      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  229.274597
# ...                                                  ...         ...
# 29382  <a refstr=STASSUN_ET_AL__2019 href=https://ui....   24.198353
# 29383  <a refstr=STASSUN_ET_AL__2019 href=https://ui....   24.198353
# 29384  <a refstr=STASSUN_ET_AL__2019 href=https://ui....   24.198353
# 29385  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  298.562439
# 29386  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  298.562439
#
#              dec
# 0      17.793251
# 1      17.793251
# 2      71.823944
# 3      71.823944
# 4      71.823944
# ...          ...
# 29382  41.403816
# 29383  41.403816
# 29384  41.403816
# 29385   8.461105
# 29386   8.461105
#
# [29387 rows x 8 columns]

# %%
hat_p_32_coord = '02 04 10.2775457769 +46 41 16.210382751'

# %%
coordinates = SkyCoord(hat_p_32_coord,unit=(u.hourangle,u.deg))

# %%
catalog = SkyCoord(ra=df.ra.values*u.degree, dec=df.dec.values*u.degree)
idx, d2d, d3d = coordinates.match_to_catalog_sky(catalog)

# %%
idx #returns index with number within list for desired object
# Out:
# array(766, dtype=int64)

# %%
df.iloc[766]
# Out:
# hostname                                               HAT-P-32
# st_teff                                                  6269.0
# st_rad                                                     1.22
# st_mass                                                     NaN
# st_logg                                                     NaN
# sy_refname    <a refstr=STASSUN_ET_AL__2019 href=https://ui....
# ra                                                    31.042761
# dec                                                   46.687851
# Name: 766, dtype: object

# %%
coordinates=SkyCoord.from_name('HAT-P-32b')

# %%
sep = coordinates.separation(catalog) #list of how far apart all objects are

# %%
matches = sep < 10*u.arcsec

# %%
matches.sum() #boolean
# Out:
# 9

# %%
df[matches]
# Out:
#      hostname  st_teff  st_rad  st_mass  st_logg  \
# 758  HAT-P-32      NaN     NaN     1.16      NaN
# 759  HAT-P-32   6001.0    1.37     1.13     4.22
# 760  HAT-P-32      NaN    1.22     1.16      NaN
# 761  HAT-P-32   3187.0     NaN      NaN     4.94
# 762  HAT-P-32      NaN     NaN      NaN      NaN
# 763  HAT-P-32   6207.0    1.22     1.16      NaN
# 764  HAT-P-32   6207.0    1.19     1.09     4.33
# 765  HAT-P-32   6207.0    1.22     1.16      NaN
# 766  HAT-P-32   6269.0    1.22      NaN      NaN
#
#                                             sy_refname         ra        dec
# 758  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 759  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 760  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 761  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 762  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 763  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 764  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 765  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851
# 766  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  31.042761  46.687851

# %%
idx, d2d, d3d = coordinates.match_to_catalog_sky(catalog)

# %%
coordinates
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (24.19934235, 41.40545674)>

# %%
catalog.search_around_sky([coordinates],seplimit=5*u.arcsec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-3901020ae193> in <module>
# ----> 1 catalog.search_around_sky([coordinates],seplimit=5*u.arcsec)
#
# ~\.conda\envs\disperse_env\lib\site-packages\astropy\coordinates\sky_coordinate.py in search_around_sky(self, searcharoundcoords, seplimit)
#    1359         from .matching import search_around_sky
#    1360
# -> 1361         return search_around_sky(searcharoundcoords, self, seplimit,
#    1362                                  storekdtree='_kdtree_sky')
#    1363
#
# ~\.conda\envs\disperse_env\lib\site-packages\astropy\coordinates\matching.py in search_around_sky(coords1, coords2, seplimit, storekdtree)
#     330         raise ValueError('seplimit must be a scalar in search_around_sky')
#     331
# --> 332     if coords1.isscalar or coords2.isscalar:
#     333         raise ValueError('One of the inputs to search_around_sky is a scalar. '
#     334                          'search_around_sky is intended for use with array '
#
# AttributeError: 'list' object has no attribute 'isscalar'
