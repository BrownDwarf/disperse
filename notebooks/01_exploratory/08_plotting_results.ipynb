# %%
import numpy as np
import pandas as pd
import os
import glob
from astropy.io import fits
import emcee
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.time import Time
import lightkurve as lk

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set_context('paper')

from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
df = pd.read_csv('../data/preliminary_results.csv')

# %%
df
# Out:
#            date             ew        ew_unc  \
# 0    2020-07-16       1.395743  1.181927e-02
# 1    2020-07-16       1.393962  1.222317e-02
# 2    2020-07-24       1.363680  1.153400e-02
# 3    2020-07-24       1.353340  1.179830e-02
# 4    2020-08-01       1.350427  1.515268e-02
# ..          ...            ...           ...
# 400  2019-10-22      -0.691427  2.336325e-02
# 401  2020-07-23      17.731751  2.055538e+00
# 402  2020-07-23  804957.885020  4.804489e+06
# 403  2020-08-01      -1.055729  1.344991e-01
# 404  2020-08-01      -0.840475  8.389069e-02
#
#                                          file_basename  \
# 0    Goldilocks_20200716T094818_v1.0_0033.spectra.fits
# 1    Goldilocks_20200716T095404_v1.0_0034.spectra.fits
# 2    Goldilocks_20200724T094542_v1.0_0025.spectra.fits
# 3    Goldilocks_20200724T095128_v1.0_0026.spectra.fits
# 4    Goldilocks_20200801T030803_v1.0_0004.spectra.fits
# ..                                                 ...
# 400  Goldilocks_20191022T020027_v1.0_0006.spectra.fits
# 401  Goldilocks_20200723T055838_v1.0_0006.spectra.fits
# 402  Goldilocks_20200723T060741_v1.0_0007.spectra.fits
# 403  Goldilocks_20200801T052720_v1.0_0023.spectra.fits
# 404  Goldilocks_20200801T053624_v1.0_0024.spectra.fits
#
#                                          full_filepath  gaussian_width  \
# 0    ../data/HPF/Helium-transit-data\HAT-P-11b\P4\G...        1.106646
# 1    ../data/HPF/Helium-transit-data\HAT-P-11b\P4\G...        1.105402
# 2    ../data/HPF/Helium-transit-data\HAT-P-11b\P4\G...        1.020919
# 3    ../data/HPF/Helium-transit-data\HAT-P-11b\P4\G...        1.016422
# 4    ../data/HPF/Helium-transit-data\HAT-P-11b\P4\G...        1.006933
# ..                                                 ...             ...
# 400  ../data/HPF/Helium-transit-data\WASP-69b\out-o...        1.343556
# 401  ../data/HPF/Helium-transit-data\WASP-80b\Goldi...        7.572096
# 402  ../data/HPF/Helium-transit-data\WASP-80b\Goldi...   990695.465321
# 403  ../data/HPF/Helium-transit-data\WASP-80b\Goldi...        1.575354
# 404  ../data/HPF/Helium-transit-data\WASP-80b\Goldi...        1.442422
#
#      gaussian_width_unc  int_wv            jd  n_samples  obs_line_center  \
# 0          8.985081e-03  8542.0  2.459047e+06     5000.0     8.542580e+03
# 1          9.202246e-03  8542.0  2.459047e+06     5000.0     8.542570e+03
# 2          8.568031e-03  8542.0  2.459055e+06     5000.0     8.542622e+03
# 3          8.953680e-03  8542.0  2.459055e+06     5000.0     8.542621e+03
# 4          1.134170e-02  8542.0  2.459063e+06     5000.0     8.542646e+03
# ..                  ...     ...           ...        ...              ...
# 400        2.878386e-02  8542.0  2.458779e+06     5000.0     8.541701e+03
# 401        1.366191e+00  8542.0  2.459054e+06     5000.0     8.534557e+03
# 402        5.882518e+06  8542.0  2.459054e+06     5000.0    -8.794204e+07
# 403        8.242386e-02  8542.0  2.459063e+06     5000.0     8.540966e+03
# 404        6.888298e-02  8542.0  2.459063e+06     5000.0     8.541084e+03
#
#      obs_line_center_unc    qidx              star_name      time
# 0           5.904067e-03  6245.0               HAT-P-11  09:48:47
# 1           6.376022e-03  6245.0               HAT-P-11  09:54:28
# 2           5.690058e-03  7146.0               HAT-P-11  09:46:12
# 3           6.048049e-03  7146.0               HAT-P-11  09:51:53
# 4           7.465504e-03  7226.0               HAT-P-11  03:08:30
# ..                   ...     ...                    ...       ...
# 400         3.355662e-02     NaN  WASP_69_out_1_after_4  02:00:52
# 401         1.348364e+00  7144.0                WASP-80  05:59:07
# 402         1.864819e+09  7144.0                WASP-80  06:08:11
# 403         9.178269e-02  7224.0                WASP-80  05:27:48
# 404         7.722516e-02  7224.0                WASP-80  05:36:52
#
# [405 rows x 15 columns]

# %%
pd.options.display.max_rows = 100

# %%
df.star_name.value_counts()
# Out:
# HAT-P-67b_IN_2                14
# HAT-P-67b_IN_1                14
# HAT-P-17b_IN_1b               11
# HAT-P-17b_IN_3                10
# HAT-P-67b_IN_3                 9
# HAT-P-67b_OUT_same3            9
# WASP_69_in_2                   7
# HAT-P-32_3_IN                  6
# HAT-P-17b                      6
# HD189733                       6
# HAT-P-11                       6
# HAT-P-17b_OUT_1b_before1       6
# HAT-P-32_1_IN                  6
# TrES-1                         6
# k2-266_in                      6
# k2-266_out_same                6
# HAT-P-12_OUT_2                 5
# Tres-1b_4_same                 5
# HAT-P-12_OUT_1                 5
# Tres-1b_IN_4                   5
# HAT-P-12_OUT_1_before2         5
# HAT-P-12_IN_2                  5
# WASP-127_OUT_before1           5
# Tres-1b_IN_2b                  5
# HAT-P-17b_OUT_3_same           4
# HAT-P-17b_OUT_3_after2         4
# WASP-80                        4
# HAT-P-17b_OUT_3_before1        4
# WASP-177_2_IN                  4
# WASP-177_1_OUT_a2              4
# HAT-P-32_3_OUT_a1              4
# k2-266_out_before1             4
# HAT-P-17b_OUT_3_after1         4
# WASP-177_2_OUT_same            4
# HAT-P-67b_OUT_1_after1         4
# Qatar-1                        4
# WASP-177_1_IN                  4
# HAT-P-17b_OUT_1_before1        4
# HAT-P-67b_OUT_3_after1         4
# Tres-1b_3after_4before2        4
# HAT-P-18b_P2_OUT_before        4
# HAT-P-67b_OUT_2_after2         4
# HAT-P-67b_OUT_1_before1        4
# kepler-396_p4                  4
# HAT-P-32_3_OUT_a2              4
# WASP-177_2_OUT_a2              4
# HAT-P-32_2_OUT_b2              4
# WASP-177_1_OUT_a1              4
# hat-p-40_p4                    4
# HAT-P-67b_OUT_2_before1        4
# Tres-1b_OUT_2b_before2         4
# HAT-P-67b_OUT_3_after2         4
# WASP_69_out_1_before_4         4
# Tres-1b_3after2_4before        4
# Tres-1b_OUT_2b_before          4
# WASP-177_1_OUT_same            4
# HAT-P-67b_OUT_2_after1         4
# HAT-P-12_OUT_1_before1         4
# WASP-177_1_OUT_b1              4
# HAT-P-32_1_OUT_b2              4
# HAT-P-17b_OUT_1b_after2p1      4
# WASP-59                        4
# k2-266_out_after1              4
# Tres-1b_OUT_2b_after           4
# HAT-P-67b_OUT_2_before2        4
# WASP_69_out_1_after_4          4
# HAT-P-32_1_OUT_b1              4
# HAT-P-67b_OUT_3_before1        4
# Hat-P-67                       4
# WASP_69_out_2_before_4         4
# HAT-P-17b_OUT_1b_after3p2      4
# Kepler-16                      4
# HAT-P-17b_OUT_3_before2        4
# WASP-177_2_OUT_a1              3
# HAT-P-67b_OUT_3_before2        3
# WASP_69_out_2_before_3         3
# WASP-177_1_OUT_b2              3
# HAT-P-18b_P2_2_OUT_before2     3
# HAT-P-32_3_OUT_b1              3
# HAT-P-12_OUT_1_after2          3
# WASP-11                        2
# hat-p-32_p4                    2
# K2-266b                        2
# HAT-P-32_3_OUT_d               2
# WASP-2                         2
# HD_189733_P4                   2
# Tres-1b_OUT_2_before1          2
# k2-141_p4                      2
# Tres-1b_3_same                 1
# WASP_69_out_2_before_1         1
# HAT-P-32_2_OUT_b1              1
# HAT-P-18b_P2_OUT_before2       1
# Name: star_name, dtype: int64

# %% [markdown]
# We retrieved the data for the planets from [NASA Exoplanet Archive](https://exoplanetarchive.ipac.caltech.edu/)

# %%
target_name = 'k2-266'
orbital_period = 2.15000820
t_c = 2455867.402743
t_c_btjd = t_c-2457000.0 #neg value means discovered before TESS

# %%
target_mask = df.star_name.str.contains(target_name)
df = df[target_mask]
keep_mask = df.ew_unc < 10 #original value = 1

# %%
df
# Out:
#            date        ew    ew_unc  \
# 253  2020-03-11 -1.208707  0.064730
# 254  2020-03-11 -1.352456  0.078029
# 255  2020-03-11 -1.351537  0.066223
# 256  2020-03-11 -1.319919  0.065225
# 257  2020-03-11 -1.159824  0.070098
# 258  2020-03-11 -1.222217  0.065890
# 259  2020-03-10 -1.252564  0.062587
# 260  2020-03-10 -1.302001  0.058929
# 261  2020-03-10 -1.313462  0.062797
# 262  2020-03-10 -1.216925  0.056997
# 263  2020-03-11 -1.218552  0.070007
# 264  2020-03-11 -1.428642  0.089475
# 265  2020-03-11 -1.209196  0.051002
# 266  2020-03-11 -1.394498  0.062370
# 267  2020-03-11 -1.258826  0.061343
# 268  2020-03-11 -1.557966  0.229264
# 269  2020-03-12 -1.208605  0.055180
# 270  2020-03-12 -1.283741  0.052812
# 271  2020-03-12 -1.368813  0.070090
# 272  2020-03-12 -1.301423  0.069984
#
#                                          file_basename  \
# 253  Goldilocks_20200311T042556_v1.0_0014.spectra.fits
# 254  Goldilocks_20200311T043503_v1.0_0015.spectra.fits
# 255  Goldilocks_20200311T044409_v1.0_0016.spectra.fits
# 256  Goldilocks_20200311T045309_v1.0_0017.spectra.fits
# 257  Goldilocks_20200311T050215_v1.0_0018.spectra.fits
# 258  Goldilocks_20200311T051120_v1.0_0019.spectra.fits
# 259  Goldilocks_20200310T071215_v1.0_0024.spectra.fits
# 260  Goldilocks_20200310T072121_v1.0_0025.spectra.fits
# 261  Goldilocks_20200310T073021_v1.0_0026.spectra.fits
# 262  Goldilocks_20200310T073928_v1.0_0027.spectra.fits
# 263  Goldilocks_20200311T070030_v1.0_0025.spectra.fits
# 264  Goldilocks_20200311T070937_v1.0_0026.spectra.fits
# 265  Goldilocks_20200311T071844_v1.0_0027.spectra.fits
# 266  Goldilocks_20200311T072744_v1.0_0028.spectra.fits
# 267  Goldilocks_20200311T073650_v1.0_0029.spectra.fits
# 268  Goldilocks_20200311T074550_v1.0_0030.spectra.fits
# 269  Goldilocks_20200312T043553_v1.0_0010.spectra.fits
# 270  Goldilocks_20200312T044500_v1.0_0011.spectra.fits
# 271  Goldilocks_20200312T045407_v1.0_0012.spectra.fits
# 272  Goldilocks_20200312T050307_v1.0_0013.spectra.fits
#
#                                          full_filepath  gaussian_width  \
# 253  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.391725
# 254  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.483276
# 255  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.458055
# 256  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.415306
# 257  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.409197
# 258  ../data/HPF/Helium-transit-data\K2-266b\in-tra...        1.360513
# 259  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.450521
# 260  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.432457
# 261  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.398967
# 262  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.360954
# 263  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.422099
# 264  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.518580
# 265  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.358069
# 266  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.438319
# 267  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.414135
# 268  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.544628
# 269  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.408949
# 270  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.410513
# 271  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.456200
# 272  ../data/HPF/Helium-transit-data\K2-266b\out-of...        1.439464
#
#      gaussian_width_unc  int_wv            jd  n_samples  obs_line_center  \
# 253            0.042456  8542.0  2.458920e+06     5000.0      8541.722564
# 254            0.045571  8542.0  2.458920e+06     5000.0      8541.605819
# 255            0.039019  8542.0  2.458920e+06     5000.0      8541.653018
# 256            0.038613  8542.0  2.458920e+06     5000.0      8541.647350
# 257            0.048543  8542.0  2.458920e+06     5000.0      8541.660844
# 258            0.043123  8542.0  2.458920e+06     5000.0      8541.746896
# 259            0.040748  8542.0  2.458919e+06     5000.0      8541.654739
# 260            0.036280  8542.0  2.458919e+06     5000.0      8541.674775
# 261            0.037251  8542.0  2.458919e+06     5000.0      8541.703604
# 262            0.037910  8542.0  2.458919e+06     5000.0      8541.728704
# 263            0.046563  8542.0  2.458920e+06     5000.0      8541.669177
# 264            0.048267  8542.0  2.458920e+06     5000.0      8541.524256
# 265            0.034282  8542.0  2.458920e+06     5000.0      8541.769226
# 266            0.035117  8542.0  2.458920e+06     5000.0      8541.652697
# 267            0.039034  8542.0  2.458920e+06     5000.0      8541.679653
# 268            0.104207  8542.0  2.458920e+06     5000.0      8541.445109
# 269            0.036606  8542.0  2.458921e+06     5000.0      8541.726464
# 270            0.032714  8542.0  2.458921e+06     5000.0      8541.736120
# 271            0.040204  8542.0  2.458921e+06     5000.0      8541.600488
# 272            0.042270  8542.0  2.458921e+06     5000.0      8541.705903
#
#      obs_line_center_unc    qidx           star_name      time
# 253             0.052201  3201.0           k2-266_in  04:26:25
# 254             0.055371  3201.0           k2-266_in  04:35:29
# 255             0.049023  3201.0           k2-266_in  04:44:33
# 256             0.048854  3201.0           k2-266_in  04:53:36
# 257             0.059591  3201.0           k2-266_in  05:02:40
# 258             0.053839  3201.0           k2-266_in  05:11:44
# 259             0.051378  3203.0  k2-266_out_before1  07:12:42
# 260             0.045620  3203.0  k2-266_out_before1  07:21:46
# 261             0.046717  3203.0  k2-266_out_before1  07:30:50
# 262             0.048169  3203.0  k2-266_out_before1  07:39:53
# 263             0.056851  3202.0     k2-266_out_same  07:01:00
# 264             0.057839  3202.0     k2-266_out_same  07:10:03
# 265             0.042504  3202.0     k2-266_out_same  07:19:07
# 266             0.042193  3202.0     k2-266_out_same  07:28:11
# 267             0.049119  3202.0     k2-266_out_same  07:37:14
# 268             0.120350  3202.0     k2-266_out_same  07:46:18
# 269             0.045015  3204.0   k2-266_out_after1  04:36:23
# 270             0.040658  3204.0   k2-266_out_after1  04:45:27
# 271             0.048724  3204.0   k2-266_out_after1  04:54:30
# 272             0.052687  3204.0   k2-266_out_after1  05:03:34

# %%
df = df[keep_mask]
in_transit_mask = df.star_name.str.contains('_IN')

# %%
df['ew']=df.ew.astype(np.float).values #change str to float
df['btjd']=df['jd']-2457000.0 #cut down JD to smaller scale

# %%
sn_ratio=2
good_data_mask=(df.ew/df.ew_unc)>sn_ratio #signal to noise ratio

# %%
df=df[good_data_mask]

# %%
x_line=df['ew'].median() #calculate horizontal line going between in/out of transit points
x_line
# Out:
# 1.103845279282398

# %%
plt.figure(figsize=(25,6))
#plt.errorbar(df.btjd, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.btjd, df.ew, 'bo', markersize=10)
plt.plot(df.btjd[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time
plt.ylim(0)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name}', fontsize=20)
plt.xlabel('Barycentric TESS Julian Date', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15)
plt.savefig(f'../figures/{target_name}.jpg')

# %%
#1st in transit plot
plt.figure(figsize=(25,6))
plt.errorbar(df.btjd, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.btjd[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time
#plt.ylim(1.05,1.25)
plt.xlim(1939.5,1940.5)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name} (1st Transit)', fontsize=20)
plt.xlabel('Barycentric TESS Julian Date', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15) 
plt.savefig(f'../figures/IN_TRANSIT_1_{target_name}.jpg')

# %%
#2nd in transit plot
plt.figure(figsize=(25,6))
plt.errorbar(df.btjd, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.btjd[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time
plt.ylim(1.0,1.2)
plt.xlim(2111.5,2112)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name} (2nd Transit)', fontsize=20)
plt.xlabel('Barycentric TESS Julian Date', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15) 
plt.savefig(f'../figures/IN_TRANSIT_2_{target_name}.jpg')

# %% [markdown]
# Let's compute the normalized phase shifted so that the transit midpoint always occurs at zero while also seeing the light curve before and after the midpoint.
#
# $$\phi=\frac{\mod(t-T_c+\frac{P}{2}\;,P)}{P} -0.5$$

# %%
df['phase']=np.mod(df.btjd-t_c_btjd+(orbital_period*0.5),orbital_period)-0.5*orbital_period
#df['normalized_phase']=(df['phase']/orbital_period)-0.5

# %%
df.describe() #max less than orbital period, normalized less than 1
# Out:
#               ew     ew_unc  gaussian_width  gaussian_width_unc  int_wv  \
# count  37.000000  37.000000       37.000000           37.000000    37.0
# mean    1.107662   0.025232        0.886546            0.019902  8542.0
# std     0.039134   0.006019        0.028773            0.004648     0.0
# min     1.030028   0.016465        0.827273            0.013191  8542.0
# 25%     1.083076   0.021938        0.866810            0.017369  8542.0
# 50%     1.103845   0.022810        0.888324            0.018201  8542.0
# 75%     1.134430   0.028587        0.904978            0.022376  8542.0
# max     1.186175   0.042977        0.958019            0.034241  8542.0
#
#                  jd  n_samples  obs_line_center  obs_line_center_unc  \
# count  3.700000e+01       37.0        37.000000            37.000000
# mean   2.459096e+06     5000.0      8543.165452             0.012529
# std    1.971388e+01        0.0         0.080122             0.003300
# min    2.459069e+06     5000.0      8543.043228             0.008109
# 25%    2.459071e+06     5000.0      8543.087762             0.010754
# 50%    2.459111e+06     5000.0      8543.185369             0.011378
# 75%    2.459112e+06     5000.0      8543.239452             0.013981
# max    2.459115e+06     5000.0      8543.288142             0.023674
#
#               qidx         btjd      phase
# count    37.000000    37.000000  37.000000
# mean   5531.702703  2095.560277  -0.225049
# std     554.925213    19.713882   0.613014
# min    4967.000000  2068.863506  -1.074142
# 25%    4969.000000  2070.869201  -0.918971
# 50%    6062.000000  2110.969856  -0.026019
# 75%    6065.000000  2111.971841   0.092682
# max    6067.000000  2114.990991   1.065995

# %%
plt.figure(figsize=(25,6))

plt.errorbar(df.normalized_phase, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.normalized_phase[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

plt.errorbar(df.normalized_phase-1, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.normalized_phase[in_transit_mask]-1, df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

plt.errorbar(df.normalized_phase+1, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.normalized_phase[in_transit_mask]+1, df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

#plt.ylim(0.9,1.32)
plt.xlim(-1.5,1.5)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name}', fontsize=20)
plt.xlabel('Normalized Orbital Phase', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15)
plt.savefig(f'../figures/{target_name}.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-61bae20522be> in <module>
#       1 plt.figure(figsize=(25,6))
#       2
# ----> 3 plt.errorbar(df.normalized_phase, df.ew, yerr=df.ew_unc, fmt='b.')
#       4 plt.plot(df.normalized_phase[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time
#       5
#
# ~\.conda\envs\disperse_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'normalized_phase'

# %%
plt.figure(figsize=(25,6))

plt.plot(df.phase, df.ew, 'bo', markersize=10)
plt.plot(df.phase[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

#plt.plot(df.normalized_phase-1, df.ew, 'bo', markersize=10)
#plt.plot(df.normalized_phase[in_transit_mask]-1, df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

#plt.plot(df.normalized_phase+1, df.ew, 'bo', markersize=10)
#plt.plot(df.normalized_phase[in_transit_mask]+1, df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time

#plt.ylim(0.9,1.32)
#plt.xlim(-2,2)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name}', fontsize=20)
plt.xlabel('Normalized Orbital Phase', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15)
plt.savefig(f'../figures/{target_name}.jpg')

# %% [markdown]
# Let's define a variable called 'shifted' in two steps.

# %%
second_half_mask = df.normalized_phase > 0.5
first_half_mask = ~second_half_mask

# %%
df['shifted']=df.normalized_phase
df.shifted[second_half_mask]=df.shifted[second_half_mask]-1
df.shifted[second_half_mask]

# %%
plt.figure(figsize=(25,6))
plt.errorbar(df.shifted, df.ew, yerr=df.ew_unc, fmt='b.')
plt.plot(df.shifted[in_transit_mask], df.ew[in_transit_mask],'ro',markersize=10) #change index to jd for time
#plt.ylim(0.9,1.32)
plt.xlim(0,1)
plt.axhline(x_line,color = 'green')
plt.suptitle(f'Equivlaneth Width of {target_name}', fontsize=20)
plt.xlabel('Normalized Orbital Phase', fontsize=15)
plt.ylabel('Equivalent Width ($\AA$)', fontsize=15)
plt.savefig(f'../figures/{target_name}.jpg')

# %% [markdown]
# # Light curve analysis with TESS

# %%
sr = lk.search_lightcurve(target_name)
lc_raw = sr[1].download()

# %%
ax = lc_raw.normalize().plot(marker='.', linestyle='none')
#ax.set_ylim(0, 1.05)
# Out:
# C:\Users\jojoa\.conda\envs\disperse_env\lib\site-packages\lightkurve\lightcurve.py:965: LightkurveWarning: The light curve already appears to be in relative units; `normalize()` will convert the light curve into relative units for a second time, which is probably not what you want.
#   warnings.warn(

# %%
lc_folded = lc_raw.fold(period=orbital_period, epoch_time=t_c_btjd).normalize()
ax = lc_folded.plot(label = target_name+' TESS Sector 18')
plt.plot(df.phase, df.ew/np.mean(df.ew), 'bo', markersize=1, label = 'HPF Calcium Triplet')
plt.legend()
#plt.ylim(0)
plt.savefig(f'../figures/TESS_EW_{target_name}_1.jpg')
# Out:
# C:\Users\jojoa\.conda\envs\disperse_env\lib\site-packages\lightkurve\lightcurve.py:965: LightkurveWarning: The light curve already appears to be in relative units; `normalize()` will convert the light curve into relative units for a second time, which is probably not what you want.
#   warnings.warn(

# %% [markdown]
# # Exploring different exposure times in the same sector

# %%
sr = lk.search_lightcurve(target_name)
lc_raw = sr[0].download()

# %%
ax = lc_raw.normalize().plot(marker='.', linestyle='none')
#ax.set_ylim(0, 1.05)

# %%
lc_folded = lc_raw.fold(period=orbital_period, epoch_time=t_c_btjd).normalize()
ax = lc_folded.plot(label = target_name+' TESS Sector 24')
plt.plot(df.phase, df.ew/np.mean(df.ew), 'bo', markersize=1, label = 'HPF Calcium Triplet')
plt.legend()
plt.savefig(f'../figures/TESS_EW_{target_name}_0.jpg')
